# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).

# %%
import os
import csv
import random
import numpy as np
from PIL import Image as PIL_Image

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.utils.data as data
from torch.optim.lr_scheduler import StepLR
from torch.autograd import Variable

from torchvision import transforms
from torchvision.models import resnet50, resnet152

# %% [markdown]
# # 랜덤 시드 고정

# %%
seed = 365

os.environ['PYTHONHASHSEED'] = str(seed)
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)    
torch.cuda.manual_seed(seed)
torch.backends.cudnn.deterministic = True

# %%
drivepath = "/content/gdrive/MyDrive"

# %%
device_type = "cuda" if torch.cuda.is_available() else "cpu"
device = torch.device(device_type)
print(device)
# Out:
# cuda

# %% [markdown]
# # 모델과 그에 맞는 데이터셋 설정
#
# Convolution layer의 출력을 FC layer에 통과시킨 뒤 매 타임스탭마다 이미지를 입력받아 키 입력을 출력하는 다대다 lstm 모델을 구성합니다.

# %%
class KartModel4(nn.Module):
  def __init__(self, num_class = 6, cnn_to_lstm = 1000, lstm_hidden = 100, num_layers = 5):
    super(KartModel4, self).__init__()
    self.num_class = num_class
    self.num_layers = num_layers
    self.hidden_size = lstm_hidden

    self.resnet = resnet50(pretrained=False)
    self.resnet.fc = nn.Sequential(
      nn.Linear(in_features=2048, out_features=cnn_to_lstm, bias=True),
      nn.ReLU(),
    )
    self.lstm = nn.LSTM(
        input_size = cnn_to_lstm,
        hidden_size = lstm_hidden,
        num_layers = num_layers,
        batch_first = True,
    )
    self.fc_1 = nn.Linear(lstm_hidden, 512)
    self.relu = nn.ReLU()
    self.fc_2 = nn.Linear(512, num_class)
    self.sigmoid = nn.Sigmoid()

  def forward(self, x_3d):
    hidden = None
    x = None
    feature_list = []
    for t in range(x_3d.size(1)):
      # with torch.no_grad():
      x = self.resnet(x_3d[:, t, :, :, :])
      out, hidden = self.lstm(x.unsqueeze(1), hidden)
    # batch first = True
    # batch, seq, hidden_size

    out = self.fc_1(out[:, -1, :])
    # 마지막 sequence
    out = self.relu(out)
    out = self.fc_2(out)
    out = self.sigmoid(out)

    return out

# %%
seq_size = 20

# %%
class KartDataSet4(data.Dataset):
  def __init__(self, csv_file):
    images = []
    labels = []

    with open(csv_file) as csvfile:
      csv_reader = csv.reader(csvfile)
      next(csv_reader, None)        # 첫번째 row 스킵
      
      for row in csv_reader:
        images.append(drivepath + '/' + row[0])
        labels.append([int(x) for x in list(row[1])])
    
    self.image_seqs = []
    self.label_1 = []

    for i in range(len(images)):
      if i - seq_size >= 0:
        self.image_seqs.append(images[i - seq_size + 1:i + 1])
        self.label_1.append(labels[i])

  def __getitem__(self, index):
    image_paths = self.image_seqs[index]
    images = [PIL_Image.open(image_path) for image_path in image_paths]
    label = self.label_1[index]

    preprocess = transforms.Compose([
      transforms.Resize((224, 224)),
      transforms.ToTensor(),
      transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),     # -1 ~ 1 로 normalize
    ])

    preprocessed_list = []
    for img in images:
      preprocessed_list.append(preprocess(img))
    
    return torch.stack(preprocessed_list), torch.Tensor(label)

  def __len__(self):
    return len(self.image_seqs)

# %%
dataset = KartDataSet4(drivepath + "/csv/kart_test.mp4.csv")
print((dataset[0][0]).shape)
print((dataset[0][1]).shape)
print((dataset[-1][0]).shape)
# seq, channel, width, height
# label
# Out:
# torch.Size([20, 3, 224, 224])
# torch.Size([6])
# torch.Size([20, 3, 224, 224])

# %% [markdown]
# # 하이퍼 파라미터 설정

# %%
num_epochs = 5
lr = 1e-4
batch_size = 4
log_interval = 10

# %%
loader = data.DataLoader(
    dataset,
    batch_size=batch_size,
    num_workers=4,
    shuffle=True
)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %% [markdown]
# # 모델 저장 설정 및 학습 가능한 레이어 확인

# %%
save_path = drivepath + "/test_model4.pt"

model = KartModel4()
# model.load_state_dict(torch.load(save_path))

for param, weight in model.named_parameters():
    print(f"param {param:20} required gradient? -> {weight.requires_grad}")
model = model.to(device)
# Out:
# param resnet.conv1.weight  required gradient? -> True
# param resnet.bn1.weight    required gradient? -> True
# param resnet.bn1.bias      required gradient? -> True
# param resnet.layer1.0.conv1.weight required gradient? -> True
# param resnet.layer1.0.bn1.weight required gradient? -> True
# param resnet.layer1.0.bn1.bias required gradient? -> True
# param resnet.layer1.0.conv2.weight required gradient? -> True
# param resnet.layer1.0.bn2.weight required gradient? -> True
# param resnet.layer1.0.bn2.bias required gradient? -> True
# param resnet.layer1.0.conv3.weight required gradient? -> True
# param resnet.layer1.0.bn3.weight required gradient? -> True
# param resnet.layer1.0.bn3.bias required gradient? -> True
# param resnet.layer1.0.downsample.0.weight required gradient? -> True
# param resnet.layer1.0.downsample.1.weight required gradient? -> True
# param resnet.layer1.0.downsample.1.bias required gradient? -> True
# param resnet.layer1.1.conv1.weight required gradient? -> True
# param resnet.layer1.1.bn1.weight required gradient? -> True
# param resnet.layer1.1.bn1.bias required gradient? -> True
# param resnet.layer1.1.conv2.weight required gradient? -> True
# param resnet.layer1.1.bn2.weight required gradient? -> True
# param resnet.layer1.1.bn2.bias required gradient? -> True
# param resnet.layer1.1.conv3.weight required gradient? -> True
# param resnet.layer1.1.bn3.weight required gradient? -> True
# param resnet.layer1.1.bn3.bias required gradient? -> True
# param resnet.layer1.2.conv1.weight required gradient? -> True
# param resnet.layer1.2.bn1.weight required gradient? -> True
# param resnet.layer1.2.bn1.bias required gradient? -> True
# param resnet.layer1.2.conv2.weight required gradient? -> True
# param resnet.layer1.2.bn2.weight required gradient? -> True
# param resnet.layer1.2.bn2.bias required gradient? -> True
# param resnet.layer1.2.conv3.weight required gradient? -> True
# param resnet.layer1.2.bn3.weight required gradient? -> True
# param resnet.layer1.2.bn3.bias required gradient? -> True
# param resnet.layer2.0.conv1.weight required gradient? -> True
# param resnet.layer2.0.bn1.weight required gradient? -> True
# param resnet.layer2.0.bn1.bias required gradient? -> True
# param resnet.layer2.0.conv2.weight required gradient? -> True
# param resnet.layer2.0.bn2.weight required gradient? -> True
# param resnet.layer2.0.bn2.bias required gradient? -> True
# param resnet.layer2.0.conv3.weight required gradient? -> True
# param resnet.layer2.0.bn3.weight required gradient? -> True
# param resnet.layer2.0.bn3.bias required gradient? -> True
# param resnet.layer2.0.downsample.0.weight required gradient? -> True
# param resnet.layer2.0.downsample.1.weight required gradient? -> True
# param resnet.layer2.0.downsample.1.bias required gradient? -> True
# param resnet.layer2.1.conv1.weight required gradient? -> True
# param resnet.layer2.1.bn1.weight required gradient? -> True
# param resnet.layer2.1.bn1.bias required gradient? -> True
# param resnet.layer2.1.conv2.weight required gradient? -> True
# param resnet.layer2.1.bn2.weight required gradient? -> True
# param resnet.layer2.1.bn2.bias required gradient? -> True
# param resnet.layer2.1.conv3.weight required gradient? -> True
# param resnet.layer2.1.bn3.weight required gradient? -> True
# param resnet.layer2.1.bn3.bias required gradient? -> True
# param resnet.layer2.2.conv1.weight required gradient? -> True
# param resnet.layer2.2.bn1.weight required gradient? -> True
# param resnet.layer2.2.bn1.bias required gradient? -> True
# param resnet.layer2.2.conv2.weight required gradient? -> True
# param resnet.layer2.2.bn2.weight required gradient? -> True
# param resnet.layer2.2.bn2.bias required gradient? -> True
# param resnet.layer2.2.conv3.weight required gradient? -> True
# param resnet.layer2.2.bn3.weight required gradient? -> True
# param resnet.layer2.2.bn3.bias required gradient? -> True
# param resnet.layer2.3.conv1.weight required gradient? -> True
# param resnet.layer2.3.bn1.weight required gradient? -> True
# param resnet.layer2.3.bn1.bias required gradient? -> True
# param resnet.layer2.3.conv2.weight required gradient? -> True
# param resnet.layer2.3.bn2.weight required gradient? -> True
# param resnet.layer2.3.bn2.bias required gradient? -> True
# param resnet.layer2.3.conv3.weight required gradient? -> True
# param resnet.layer2.3.bn3.weight required gradient? -> True
# param resnet.layer2.3.bn3.bias required gradient? -> True
# param resnet.layer3.0.conv1.weight required gradient? -> True
# param resnet.layer3.0.bn1.weight required gradient? -> True
# param resnet.layer3.0.bn1.bias required gradient? -> True
# param resnet.layer3.0.conv2.weight required gradient? -> True
# param resnet.layer3.0.bn2.weight required gradient? -> True
# param resnet.layer3.0.bn2.bias required gradient? -> True
# param resnet.layer3.0.conv3.weight required gradient? -> True
# param resnet.layer3.0.bn3.weight required gradient? -> True
# param resnet.layer3.0.bn3.bias required gradient? -> True
# param resnet.layer3.0.downsample.0.weight required gradient? -> True
# param resnet.layer3.0.downsample.1.weight required gradient? -> True
# param resnet.layer3.0.downsample.1.bias required gradient? -> True
# param resnet.layer3.1.conv1.weight required gradient? -> True
# param resnet.layer3.1.bn1.weight required gradient? -> True
# param resnet.layer3.1.bn1.bias required gradient? -> True
# param resnet.layer3.1.conv2.weight required gradient? -> True
# param resnet.layer3.1.bn2.weight required gradient? -> True
# param resnet.layer3.1.bn2.bias required gradient? -> True
# param resnet.layer3.1.conv3.weight required gradient? -> True
# param resnet.layer3.1.bn3.weight required gradient? -> True
# param resnet.layer3.1.bn3.bias required gradient? -> True
# param resnet.layer3.2.conv1.weight required gradient? -> True
# param resnet.layer3.2.bn1.weight required gradient? -> True
# param resnet.layer3.2.bn1.bias required gradient? -> True
# param resnet.layer3.2.conv2.weight required gradient? -> True
# param resnet.layer3.2.bn2.weight required gradient? -> True
# param resnet.layer3.2.bn2.bias required gradient? -> True
# param resnet.layer3.2.conv3.weight required gradient? -> True
# param resnet.layer3.2.bn3.weight required gradient? -> True
# param resnet.layer3.2.bn3.bias required gradient? -> True
# param resnet.layer3.3.conv1.weight required gradient? -> True
# param resnet.layer3.3.bn1.weight required gradient? -> True
# param resnet.layer3.3.bn1.bias required gradient? -> True
# param resnet.layer3.3.conv2.weight required gradient? -> True
# param resnet.layer3.3.bn2.weight required gradient? -> True
# param resnet.layer3.3.bn2.bias required gradient? -> True
# param resnet.layer3.3.conv3.weight required gradient? -> True
# param resnet.layer3.3.bn3.weight required gradient? -> True
# param resnet.layer3.3.bn3.bias required gradient? -> True
# param resnet.layer3.4.conv1.weight required gradient? -> True
# param resnet.layer3.4.bn1.weight required gradient? -> True
# param resnet.layer3.4.bn1.bias required gradient? -> True
# param resnet.layer3.4.conv2.weight required gradient? -> True
# param resnet.layer3.4.bn2.weight required gradient? -> True
# param resnet.layer3.4.bn2.bias required gradient? -> True
# param resnet.layer3.4.conv3.weight required gradient? -> True
# param resnet.layer3.4.bn3.weight required gradient? -> True
# param resnet.layer3.4.bn3.bias required gradient? -> True
# param resnet.layer3.5.conv1.weight required gradient? -> True
# param resnet.layer3.5.bn1.weight required gradient? -> True
# param resnet.layer3.5.bn1.bias required gradient? -> True
# param resnet.layer3.5.conv2.weight required gradient? -> True
# param resnet.layer3.5.bn2.weight required gradient? -> True
# param resnet.layer3.5.bn2.bias required gradient? -> True
# param resnet.layer3.5.conv3.weight required gradient? -> True
# param resnet.layer3.5.bn3.weight required gradient? -> True
# param resnet.layer3.5.bn3.bias required gradient? -> True
# param resnet.layer4.0.conv1.weight required gradient? -> True
# param resnet.layer4.0.bn1.weight required gradient? -> True
# param resnet.layer4.0.bn1.bias required gradient? -> True
# param resnet.layer4.0.conv2.weight required gradient? -> True
# param resnet.layer4.0.bn2.weight required gradient? -> True
# param resnet.layer4.0.bn2.bias required gradient? -> True
# param resnet.layer4.0.conv3.weight required gradient? -> True
# param resnet.layer4.0.bn3.weight required gradient? -> True
# param resnet.layer4.0.bn3.bias required gradient? -> True
# param resnet.layer4.0.downsample.0.weight required gradient? -> True
# param resnet.layer4.0.downsample.1.weight required gradient? -> True
# param resnet.layer4.0.downsample.1.bias required gradient? -> True
# param resnet.layer4.1.conv1.weight required gradient? -> True
# param resnet.layer4.1.bn1.weight required gradient? -> True
# param resnet.layer4.1.bn1.bias required gradient? -> True
# param resnet.layer4.1.conv2.weight required gradient? -> True
# param resnet.layer4.1.bn2.weight required gradient? -> True
# param resnet.layer4.1.bn2.bias required gradient? -> True
# param resnet.layer4.1.conv3.weight required gradient? -> True
# param resnet.layer4.1.bn3.weight required gradient? -> True
# param resnet.layer4.1.bn3.bias required gradient? -> True
# param resnet.layer4.2.conv1.weight required gradient? -> True
# param resnet.layer4.2.bn1.weight required gradient? -> True
# param resnet.layer4.2.bn1.bias required gradient? -> True
# param resnet.layer4.2.conv2.weight required gradient? -> True
# param resnet.layer4.2.bn2.weight required gradient? -> True
# param resnet.layer4.2.bn2.bias required gradient? -> True
# param resnet.layer4.2.conv3.weight required gradient? -> True
# param resnet.layer4.2.bn3.weight required gradient? -> True
# param resnet.layer4.2.bn3.bias required gradient? -> True
# param resnet.fc.0.weight   required gradient? -> True
# param resnet.fc.0.bias     required gradient? -> True
# param lstm.weight_ih_l0    required gradient? -> True
# param lstm.weight_hh_l0    required gradient? -> True
# param lstm.bias_ih_l0      required gradient? -> True
# param lstm.bias_hh_l0      required gradient? -> True
# param lstm.weight_ih_l1    required gradient? -> True
# param lstm.weight_hh_l1    required gradient? -> True
# param lstm.bias_ih_l1      required gradient? -> True
# param lstm.bias_hh_l1      required gradient? -> True
# param lstm.weight_ih_l2    required gradient? -> True
# param lstm.weight_hh_l2    required gradient? -> True
# param lstm.bias_ih_l2      required gradient? -> True
# param lstm.bias_hh_l2      required gradient? -> True
# param lstm.weight_ih_l3    required gradient? -> True
# param lstm.weight_hh_l3    required gradient? -> True
# param lstm.bias_ih_l3      required gradient? -> True
# param lstm.bias_hh_l3      required gradient? -> True
# param lstm.weight_ih_l4    required gradient? -> True
# param lstm.weight_hh_l4    required gradient? -> True
# param lstm.bias_ih_l4      required gradient? -> True
# param lstm.bias_hh_l4      required gradient? -> True
# param fc_1.weight          required gradient? -> True
# param fc_1.bias            required gradient? -> True
# param fc_2.weight          required gradient? -> True
# param fc_2.bias            required gradient? -> True

# %% [markdown]
# # Loss, Optimizer, Scheduler 설정

# %%
# criterion = nn.CrossEntropyLoss()
# criterion = nn.BCEWithLogitsLoss()
criterion = nn.BCELoss()
optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=5e-4)
scheduler = StepLR(optimizer, 5, gamma=0.5)

# %%
a = 0
for i in loader:
  a = i
  break
  
inputs, labels = a
print(inputs.shape)
print(labels.shape)
# batch, seq, channel, width, height
# batch, seq, label
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# torch.Size([4, 20, 3, 224, 224])
# torch.Size([4, 6])

# %% [markdown]
# # 데이터로더, 모델 인풋, 아웃풋 점검

# %%
from torchvision.transforms import ToPILImage
from IPython.display import Image
to_img = ToPILImage()

display(to_img(inputs[0][0]))
display(to_img(inputs[0][1]))

inputs = inputs.to(device)
labels = labels.to(device)
outs = model(inputs)
print(outs.shape)
# print(outs > 0.5)
# print(((outs > 0.5) == labels).sum(axis=1))
print((((outs > 0.5) == labels).sum(axis=1) == 6).sum())
loss = criterion(outs, labels)
print(labels.shape)
print(loss.cpu())
# print(((labels == (outs > 0.5)).sum(axis=2) == 6).sum())
# print(outs > 0.5)
# print(labels)
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FAEB6876A50>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FAEB6965610>
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# torch.Size([4, 6])
# tensor(0, device='cuda:0')
# torch.Size([4, 6])
# tensor(0.6904, grad_fn=<CopyBackwards>)

# %% [markdown]
# # 학습 진행상황 확인을 위한 wandb 설정

# %%
# !pip install wandb
# Out:
# Requirement already satisfied: wandb in /usr/local/lib/python3.7/dist-packages (0.10.32)
# Requirement already satisfied: subprocess32>=3.5.3 in /usr/local/lib/python3.7/dist-packages (from wandb) (3.5.4)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from wandb) (3.13)
# Requirement already satisfied: sentry-sdk>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (1.1.0)
# Requirement already satisfied: promise<3,>=2.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.3)
# Requirement already satisfied: protobuf>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (3.12.4)
# Requirement already satisfied: six>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (1.15.0)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (0.4.0)
# Requirement already satisfied: pathtools in /usr/local/lib/python3.7/dist-packages (from wandb) (0.1.2)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.23.0)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.8.1)
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (7.1.2)
# Requirement already satisfied: configparser>=3.8.1 in /usr/local/lib/python3.7/dist-packages (from wandb) (5.0.2)
# Requirement already satisfied: shortuuid>=0.5.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (1.0.1)
# Requirement already satisfied: GitPython>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (3.1.18)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (5.4.8)
# Requirement already satisfied: urllib3>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from sentry-sdk>=0.4.0->wandb) (1.24.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from sentry-sdk>=0.4.0->wandb) (2021.5.30)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from protobuf>=3.12.0->wandb) (57.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (3.0.4)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.7/dist-packages (from GitPython>=1.0.0->wandb) (4.0.7)
# Requirement already satisfied: typing-extensions>=3.7.4.0; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from GitPython>=1.0.0->wandb) (3.7.4.3)
# Requirement already satisfied: smmap<5,>=3.0.1 in /usr/local/lib/python3.7/dist-packages (from gitdb<5,>=4.0.1->GitPython>=1.0.0->wandb) (4.0.0)

# %%
import wandb

wandb.login()
# Out:
# wandb: Currently logged in as: junhyeokk (use `wandb login --relogin` to force relogin)
# True

# %%
config = {}
config['n_epochs'] = num_epochs
config['batch_sze'] = batch_size
# config['lr'] = lr


wandb.init(project="boomhill24_3", config=config)
# Out:
#                 Tracking run with wandb version 0.10.32<br/>
#                 Syncing run <strong style="color:#cdcd00">magic-totem-3</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/junhyeokk/boomhill24_3" target="_blank">https://wandb.ai/junhyeokk/boomhill24_3</a><br/>
#                 Run page: <a href="https://wandb.ai/junhyeokk/boomhill24_3/runs/kiekcll4" target="_blank">https://wandb.ai/junhyeokk/boomhill24_3/runs/kiekcll4</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210626_155736-kiekcll4</code><br/><br/>
# <h1>Run(kiekcll4)</h1><iframe src="https://wandb.ai/junhyeokk/boomhill24_3/runs/kiekcll4" style="border:none;width:100%;height:400px"></iframe>

# %% [markdown]
# # 학습 진행 및 저장

# %%
for epoch in range(num_epochs):
  model.train()
  loss_value = 0
  matches = 0
  
  for idx, train_batch in enumerate(loader):
    inputs, labels = train_batch
    inputs = inputs.to(device)
    labels = labels.to(device)

    outs = model(inputs)
    preds = (outs > 0.5)
    loss = criterion(outs, labels)

    loss.backward()
    optimizer.step()
    optimizer.zero_grad()

    loss_value += loss.item()
    # matches += (preds == labels).sum().item()
    matches += ((preds == labels).sum(axis = 1) == 6).sum()

    if (idx + 1) % log_interval == 0:
      train_loss = loss_value / log_interval
      train_acc = matches / seq_size / batch_size / log_interval
      current_lr = scheduler.get_last_lr()

      wandb.log({"epoch" : epoch, "training_loss" : train_loss, "training_acc" : train_acc, "learning_rate" : current_lr})
      print(
          f"Epoch[{epoch + 1}/{num_epochs}]({idx + 1}/{len(loader)}) || "
          # f"training loss {train_loss:4.4} || lr {current_lr}"
          f"training loss {train_loss:4.4} || training accuracy {train_acc:4.2%} || lr {current_lr}"
      )

      loss_value = 0
      matches = 0

    scheduler.step()
    
  torch.save(model.state_dict(), save_path)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Epoch[0/5](10/240) || training loss 0.6841 || training accuracy 0.00% || lr [5e-05]
# Epoch[0/5](20/240) || training loss 0.6795 || training accuracy 1.50% || lr [1.25e-05]
# Epoch[0/5](30/240) || training loss 0.6795 || training accuracy 1.13% || lr [3.125e-06]
# Epoch[0/5](40/240) || training loss 0.6776 || training accuracy 1.88% || lr [7.8125e-07]
# Epoch[0/5](50/240) || training loss 0.6805 || training accuracy 0.75% || lr [1.953125e-07]
# Epoch[0/5](60/240) || training loss 0.6786 || training accuracy 1.25% || lr [4.8828125e-08]
# Epoch[0/5](70/240) || training loss 0.6765 || training accuracy 2.25% || lr [1.220703125e-08]
# Epoch[0/5](80/240) || training loss 0.6792 || training accuracy 1.00% || lr [3.0517578125e-09]
# Epoch[0/5](90/240) || training loss 0.6804 || training accuracy 1.25% || lr [7.62939453125e-10]
# Epoch[0/5](100/240) || training loss 0.6773 || training accuracy 1.13% || lr [1.9073486328125e-10]
# Epoch[0/5](110/240) || training loss 0.6786 || training accuracy 1.63% || lr [4.76837158203125e-11]
# Epoch[0/5](120/240) || training loss 0.678 || training accuracy 1.50% || lr [1.1920928955078126e-11]
# Epoch[0/5](130/240) || training loss 0.6781 || training accuracy 1.50% || lr [2.9802322387695314e-12]
# Epoch[0/5](140/240) || training loss 0.678 || training accuracy 0.75% || lr [7.450580596923828e-13]
# Epoch[0/5](150/240) || training loss 0.6785 || training accuracy 1.63% || lr [1.862645149230957e-13]
# Epoch[0/5](160/240) || training loss 0.6794 || training accuracy 1.38% || lr [4.656612873077393e-14]
# Epoch[0/5](170/240) || training loss 0.6806 || training accuracy 1.13% || lr [1.1641532182693482e-14]
# Epoch[0/5](180/240) || training loss 0.6797 || training accuracy 0.75% || lr [2.9103830456733705e-15]
# Epoch[0/5](190/240) || training loss 0.6814 || training accuracy 1.13% || lr [7.275957614183426e-16]
# Epoch[0/5](200/240) || training loss 0.6767 || training accuracy 1.50% || lr [1.8189894035458566e-16]
# Epoch[0/5](210/240) || training loss 0.678 || training accuracy 1.88% || lr [4.5474735088646414e-17]
# Epoch[0/5](220/240) || training loss 0.6781 || training accuracy 1.13% || lr [1.1368683772161604e-17]
# Epoch[0/5](230/240) || training loss 0.6787 || training accuracy 1.50% || lr [2.842170943040401e-18]
# Epoch[0/5](240/240) || training loss 0.6775 || training accuracy 1.25% || lr [7.105427357601002e-19]
# Epoch[1/5](10/240) || training loss 0.6765 || training accuracy 1.75% || lr [1.7763568394002505e-19]
# Epoch[1/5](20/240) || training loss 0.677 || training accuracy 1.38% || lr [4.4408920985006264e-20]
# Epoch[1/5](30/240) || training loss 0.6784 || training accuracy 1.50% || lr [1.1102230246251566e-20]
# Epoch[1/5](40/240) || training loss 0.6789 || training accuracy 1.00% || lr [2.7755575615628915e-21]
# Epoch[1/5](50/240) || training loss 0.6806 || training accuracy 1.00% || lr [6.938893903907229e-22]
# Epoch[1/5](60/240) || training loss 0.6786 || training accuracy 1.38% || lr [1.7347234759768072e-22]
# Epoch[1/5](70/240) || training loss 0.6791 || training accuracy 1.50% || lr [4.336808689942018e-23]
# Epoch[1/5](80/240) || training loss 0.6801 || training accuracy 0.88% || lr [1.0842021724855045e-23]
# Epoch[1/5](90/240) || training loss 0.6783 || training accuracy 1.63% || lr [2.7105054312137612e-24]
# Epoch[1/5](100/240) || training loss 0.6788 || training accuracy 1.00% || lr [6.776263578034403e-25]
# Epoch[1/5](110/240) || training loss 0.6786 || training accuracy 1.25% || lr [1.6940658945086008e-25]
# Epoch[1/5](120/240) || training loss 0.6776 || training accuracy 1.88% || lr [4.235164736271502e-26]
# Epoch[1/5](130/240) || training loss 0.679 || training accuracy 0.88% || lr [1.0587911840678755e-26]
# Epoch[1/5](140/240) || training loss 0.677 || training accuracy 1.63% || lr [2.6469779601696887e-27]
# Epoch[1/5](150/240) || training loss 0.6801 || training accuracy 1.38% || lr [6.617444900424222e-28]
# Epoch[1/5](160/240) || training loss 0.6785 || training accuracy 1.75% || lr [1.6543612251060554e-28]
# Epoch[1/5](170/240) || training loss 0.6769 || training accuracy 1.50% || lr [4.1359030627651386e-29]
# Epoch[1/5](180/240) || training loss 0.6793 || training accuracy 1.38% || lr [1.0339757656912846e-29]
# Epoch[1/5](190/240) || training loss 0.6803 || training accuracy 0.88% || lr [2.5849394142282116e-30]
# Epoch[1/5](200/240) || training loss 0.6788 || training accuracy 1.38% || lr [6.462348535570529e-31]
# Epoch[1/5](210/240) || training loss 0.6769 || training accuracy 1.63% || lr [1.6155871338926323e-31]
# Epoch[1/5](220/240) || training loss 0.6784 || training accuracy 1.00% || lr [4.0389678347315806e-32]
# Epoch[1/5](230/240) || training loss 0.6797 || training accuracy 1.00% || lr [1.0097419586828952e-32]
# Epoch[1/5](240/240) || training loss 0.6786 || training accuracy 1.63% || lr [2.524354896707238e-33]
# Epoch[2/5](10/240) || training loss 0.678 || training accuracy 1.50% || lr [6.310887241768095e-34]
# Epoch[2/5](20/240) || training loss 0.6797 || training accuracy 0.88% || lr [1.5777218104420237e-34]
# Epoch[2/5](30/240) || training loss 0.6786 || training accuracy 1.25% || lr [3.944304526105059e-35]
# Epoch[2/5](40/240) || training loss 0.6809 || training accuracy 0.63% || lr [9.860761315262648e-36]
# Epoch[2/5](50/240) || training loss 0.6785 || training accuracy 1.13% || lr [2.465190328815662e-36]
# Epoch[2/5](60/240) || training loss 0.6778 || training accuracy 1.63% || lr [6.162975822039155e-37]
# Epoch[2/5](70/240) || training loss 0.6786 || training accuracy 1.25% || lr [1.5407439555097888e-37]
# Epoch[2/5](80/240) || training loss 0.6792 || training accuracy 1.38% || lr [3.851859888774472e-38]
# Epoch[2/5](90/240) || training loss 0.6774 || training accuracy 1.63% || lr [9.62964972193618e-39]
# Epoch[2/5](100/240) || training loss 0.679 || training accuracy 0.88% || lr [2.407412430484045e-39]
# Epoch[2/5](110/240) || training loss 0.6804 || training accuracy 0.63% || lr [6.018531076210112e-40]
# Epoch[2/5](120/240) || training loss 0.6783 || training accuracy 1.25% || lr [1.504632769052528e-40]
# Epoch[2/5](130/240) || training loss 0.6791 || training accuracy 1.50% || lr [3.76158192263132e-41]
# Epoch[2/5](140/240) || training loss 0.6773 || training accuracy 1.88% || lr [9.4039548065783e-42]
# Epoch[2/5](150/240) || training loss 0.679 || training accuracy 1.38% || lr [2.350988701644575e-42]
# Epoch[2/5](160/240) || training loss 0.6782 || training accuracy 1.63% || lr [5.877471754111438e-43]
# Epoch[2/5](170/240) || training loss 0.6784 || training accuracy 1.38% || lr [1.4693679385278595e-43]
# Epoch[2/5](180/240) || training loss 0.6796 || training accuracy 0.88% || lr [3.6734198463196486e-44]
# Epoch[2/5](190/240) || training loss 0.677 || training accuracy 1.75% || lr [9.183549615799122e-45]
# Epoch[2/5](200/240) || training loss 0.6768 || training accuracy 2.00% || lr [2.2958874039497804e-45]
# Epoch[2/5](210/240) || training loss 0.6787 || training accuracy 1.38% || lr [5.739718509874451e-46]
# Epoch[2/5](220/240) || training loss 0.6773 || training accuracy 1.38% || lr [1.4349296274686127e-46]
# Epoch[2/5](230/240) || training loss 0.6796 || training accuracy 1.63% || lr [3.587324068671532e-47]
# Epoch[2/5](240/240) || training loss 0.6783 || training accuracy 1.38% || lr [8.96831017167883e-48]
# Epoch[3/5](10/240) || training loss 0.6781 || training accuracy 1.38% || lr [2.2420775429197074e-48]
# Epoch[3/5](20/240) || training loss 0.6783 || training accuracy 1.38% || lr [5.6051938572992686e-49]
# Epoch[3/5](30/240) || training loss 0.6779 || training accuracy 1.00% || lr [1.4012984643248171e-49]
# Epoch[3/5](40/240) || training loss 0.6787 || training accuracy 2.13% || lr [3.503246160812043e-50]
# Epoch[3/5](50/240) || training loss 0.6785 || training accuracy 1.63% || lr [8.758115402030107e-51]
# Epoch[3/5](60/240) || training loss 0.6777 || training accuracy 1.13% || lr [2.1895288505075268e-51]
# Epoch[3/5](70/240) || training loss 0.6789 || training accuracy 1.13% || lr [5.473822126268817e-52]
# Epoch[3/5](80/240) || training loss 0.679 || training accuracy 1.75% || lr [1.3684555315672042e-52]
# Epoch[3/5](90/240) || training loss 0.6792 || training accuracy 0.75% || lr [3.4211388289180106e-53]
# Epoch[3/5](100/240) || training loss 0.6782 || training accuracy 1.13% || lr [8.552847072295026e-54]
# Epoch[3/5](110/240) || training loss 0.6772 || training accuracy 1.88% || lr [2.1382117680737566e-54]
# Epoch[3/5](120/240) || training loss 0.681 || training accuracy 1.00% || lr [5.3455294201843915e-55]
# Epoch[3/5](130/240) || training loss 0.6796 || training accuracy 1.13% || lr [1.3363823550460979e-55]
# Epoch[3/5](140/240) || training loss 0.6782 || training accuracy 1.38% || lr [3.3409558876152447e-56]
# Epoch[3/5](150/240) || training loss 0.6776 || training accuracy 1.75% || lr [8.352389719038112e-57]
# Epoch[3/5](160/240) || training loss 0.679 || training accuracy 1.38% || lr [2.088097429759528e-57]
# Epoch[3/5](170/240) || training loss 0.6783 || training accuracy 1.13% || lr [5.22024357439882e-58]
# Epoch[3/5](180/240) || training loss 0.6794 || training accuracy 1.00% || lr [1.305060893599705e-58]
# Epoch[3/5](190/240) || training loss 0.6769 || training accuracy 1.63% || lr [3.2626522339992624e-59]
# Epoch[3/5](200/240) || training loss 0.6788 || training accuracy 1.00% || lr [8.156630584998156e-60]
# Epoch[3/5](210/240) || training loss 0.6779 || training accuracy 1.63% || lr [2.039157646249539e-60]
# Epoch[3/5](220/240) || training loss 0.679 || training accuracy 0.88% || lr [5.0978941156238475e-61]
# Epoch[3/5](230/240) || training loss 0.6797 || training accuracy 1.63% || lr [1.2744735289059619e-61]
# Epoch[3/5](240/240) || training loss 0.6787 || training accuracy 1.38% || lr [3.1861838222649047e-62]
# Epoch[4/5](10/240) || training loss 0.6783 || training accuracy 1.63% || lr [7.965459555662262e-63]
# Epoch[4/5](20/240) || training loss 0.6784 || training accuracy 1.13% || lr [1.9913648889155654e-63]
# Epoch[4/5](30/240) || training loss 0.6795 || training accuracy 1.38% || lr [4.9784122222889136e-64]
# Epoch[4/5](40/240) || training loss 0.6763 || training accuracy 1.88% || lr [1.2446030555722284e-64]
# Epoch[4/5](50/240) || training loss 0.6787 || training accuracy 1.00% || lr [3.111507638930571e-65]
# Epoch[4/5](60/240) || training loss 0.6778 || training accuracy 1.38% || lr [7.778769097326428e-66]
# Epoch[4/5](70/240) || training loss 0.6781 || training accuracy 1.63% || lr [1.944692274331607e-66]
# Epoch[4/5](80/240) || training loss 0.6809 || training accuracy 0.88% || lr [4.861730685829017e-67]
# Epoch[4/5](90/240) || training loss 0.6774 || training accuracy 1.38% || lr [1.2154326714572543e-67]
# Epoch[4/5](100/240) || training loss 0.6806 || training accuracy 1.00% || lr [3.0385816786431357e-68]
# Epoch[4/5](110/240) || training loss 0.6791 || training accuracy 1.38% || lr [7.596454196607839e-69]
# Epoch[4/5](120/240) || training loss 0.6779 || training accuracy 1.63% || lr [1.8991135491519598e-69]
# Epoch[4/5](130/240) || training loss 0.677 || training accuracy 1.75% || lr [4.7477838728798996e-70]
# Epoch[4/5](140/240) || training loss 0.679 || training accuracy 0.75% || lr [1.1869459682199749e-70]
# Epoch[4/5](150/240) || training loss 0.6788 || training accuracy 1.00% || lr [2.9673649205499373e-71]
# Epoch[4/5](160/240) || training loss 0.679 || training accuracy 1.13% || lr [7.418412301374843e-72]
# Epoch[4/5](170/240) || training loss 0.6779 || training accuracy 1.50% || lr [1.8546030753437108e-72]
# Epoch[4/5](180/240) || training loss 0.6806 || training accuracy 1.00% || lr [4.636507688359277e-73]
# Epoch[4/5](190/240) || training loss 0.678 || training accuracy 1.75% || lr [1.1591269220898192e-73]
# Epoch[4/5](200/240) || training loss 0.6799 || training accuracy 0.88% || lr [2.897817305224548e-74]
# Epoch[4/5](210/240) || training loss 0.677 || training accuracy 2.00% || lr [7.24454326306137e-75]
# Epoch[4/5](220/240) || training loss 0.6782 || training accuracy 1.25% || lr [1.8111358157653426e-75]
# Epoch[4/5](230/240) || training loss 0.6802 || training accuracy 1.38% || lr [4.5278395394133564e-76]
# Epoch[4/5](240/240) || training loss 0.6775 || training accuracy 1.50% || lr [1.1319598848533391e-76]

# %%
print(len(loader))
print(len(dataset))
# Out:
# 240
# 959

# %%
display(to_img(inputs[0][0]))
display(to_img(inputs[0][1]))
display(to_img(inputs[0][19]))

inputs = inputs.to(device)
labels = labels.to(device)
print(inputs.shape)
outs = model(inputs)
print(outs.shape)
print(outs > 0.5)
# print(((outs > 0.5) == labels).sum(axis=1))
print((((outs > 0.5) == labels).sum(axis=1) == 6).sum())
loss = criterion(outs, labels)
print(labels.shape)
print(loss.cpu())
# print(((labels == (outs > 0.5)).sum(axis=2) == 6).sum())
# print(outs > 0.5)
# print(labels)
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FAC1E13E490>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FA9F9C8ABD0>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FAC1E13E450>
# torch.Size([3, 20, 3, 224, 224])
# torch.Size([3, 6])
# tensor([[ True, False,  True, False, False, False],
#         [ True, False,  True, False, False, False],
#         [ True, False,  True, False, False, False]], device='cuda:0')
# tensor(0, device='cuda:0')
# torch.Size([3, 6])
# tensor(0.6842, grad_fn=<CopyBackwards>)
