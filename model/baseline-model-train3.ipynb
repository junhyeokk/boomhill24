# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).

# %%
import os
import csv
import random
import numpy as np
from PIL import Image as PIL_Image

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.utils.data as data
from torch.optim.lr_scheduler import StepLR
from torch.autograd import Variable

from torchvision import transforms
from torchvision.models import resnet50, resnet152

# %% [markdown]
# # 랜덤 시드 고정

# %%
seed = 365

os.environ['PYTHONHASHSEED'] = str(seed)
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)    
torch.cuda.manual_seed(seed)
torch.backends.cudnn.deterministic = True

# %%
drivepath = "/content/gdrive/MyDrive"

# %%
device_type = "cuda" if torch.cuda.is_available() else "cpu"
device = torch.device(device_type)
print(device)
# Out:
# cuda

# %% [markdown]
# # 모델과 그에 맞는 데이터셋 설정
#
# Convolution layer의 출력을 FC layer에 통과시킨 뒤 매 타임스탭마다 이미지를 입력받아 키 입력을 출력하는 다대다 lstm 모델을 구성합니다.

# %%
class KartModel3(nn.Module):
  def __init__(self, num_class = 6, cnn_to_lstm = 1000, lstm_hidden = 100, num_layers = 5):
    super(KartModel3, self).__init__()
    self.num_class = num_class
    self.num_layers = num_layers
    self.hidden_size = lstm_hidden

    self.resnet = resnet152(pretrained=False)
    self.resnet.fc = nn.Sequential(
      nn.Linear(in_features=2048, out_features=cnn_to_lstm, bias=True),
      nn.ReLU(),
    )
    self.lstm = nn.LSTM(
        input_size = cnn_to_lstm,
        hidden_size = lstm_hidden,
        num_layers = num_layers,
        batch_first = True,
    )
    self.fc_1 = nn.Linear(lstm_hidden, 512)
    self.relu = nn.ReLU()
    self.fc_2 = nn.Linear(512, num_class)
    self.sigmoid = nn.Sigmoid()

  def forward(self, x_3d):
    hidden = None
    x = None
    feature_list = []
    for t in range(x_3d.size(1)):
      # with torch.no_grad():
      feature_list.append(self.resnet(x_3d[:, t, :, :, :]))
    x = torch.stack(feature_list, dim=1)
    out, hidden = self.lstm(x, hidden)
    # batch, seq, hidden_size

    out = self.fc_1(out)
    out = self.relu(out)
    out = self.fc_2(out)
    out = self.sigmoid(out)

    return out

  # def forward2(self, input_image,
  #             h_0 = Variable(torch.zeros(self.num_layers, x.size(0), self.hidden_size)).to(device),
  #             c_0 = Variable(torch.zeros(self.num_layers, x.size(0), self.hidden_size)).to(device)):
  #   out = self.backbone(input_image)

  #   output, (hn, cn) = self.lstm(out, (h_0, c_0))
  #   hn = hn.view(-1, self.hidden_size)
  #   out = self.relu(hn)
  #   out = self.fc_1(out)
  #   out = self.relu(out)
  #   out = self.fc_2(out)
  #   out = self.sigmoid(out)

  #   return out

# %%
seq_size = 5

# %%
class KartDataSet3(data.Dataset):
  def __init__(self, csv_file):
    images = []
    labels = []

    with open(csv_file) as csvfile:
      csv_reader = csv.reader(csvfile)
      next(csv_reader, None)        # 첫번째 row 스킵
      
      for row in csv_reader:
        images.append(drivepath + '/' + row[0])
        labels.append([int(x) for x in list(row[1])])
    
    self.image_seqs = []
    self.label_seqs = []

    for i in range(len(images)):
      if i + seq_size <= len(images):
        self.image_seqs.append(images[i:i + seq_size])
        self.label_seqs.append(labels[i:i + seq_size])

  def __getitem__(self, index):
    image_paths = self.image_seqs[index]
    images = [PIL_Image.open(image_path) for image_path in image_paths]
    labels = self.label_seqs[index]

    preprocess = transforms.Compose([
      transforms.Resize((224, 224)),
      transforms.ToTensor(),
      transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),     # -1 ~ 1 로 normalize
    ])

    preprocessed_list = []
    for img in images:
      preprocessed_list.append(preprocess(img))
    
    return torch.stack(preprocessed_list), torch.Tensor(labels)

  def __len__(self):
    return len(self.image_seqs)

# %%
dataset = KartDataSet3(drivepath + "/csv/kart_test.mp4.csv")
print((dataset[0][0]).shape)
print((dataset[0][1]).shape)
print((dataset[-1][0]).shape)
# seq, channel, width, height
# seq, label
# Out:
# torch.Size([5, 3, 224, 224])
# torch.Size([5, 6])
# torch.Size([5, 3, 224, 224])

# %% [markdown]
# # 하이퍼 파라미터 설정

# %%
num_epochs = 20
lr = 1e-4
batch_size = 4
log_interval = 10

# %%
loader = data.DataLoader(
    dataset,
    batch_size=batch_size,
    num_workers=4,
    shuffle=False
)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %% [markdown]
# # 모델 저장 설정 및 학습 가능한 레이어 확인

# %%
save_path = drivepath + "/test_model3.pt"

model = KartModel3()
# model.load_state_dict(torch.load(save_path))

for param, weight in model.named_parameters():
    print(f"param {param:20} required gradient? -> {weight.requires_grad}")
model = model.to(device)
# Out:
# param resnet.conv1.weight  required gradient? -> True
# param resnet.bn1.weight    required gradient? -> True
# param resnet.bn1.bias      required gradient? -> True
# param resnet.layer1.0.conv1.weight required gradient? -> True
# param resnet.layer1.0.bn1.weight required gradient? -> True
# param resnet.layer1.0.bn1.bias required gradient? -> True
# param resnet.layer1.0.conv2.weight required gradient? -> True
# param resnet.layer1.0.bn2.weight required gradient? -> True
# param resnet.layer1.0.bn2.bias required gradient? -> True
# param resnet.layer1.0.conv3.weight required gradient? -> True
# param resnet.layer1.0.bn3.weight required gradient? -> True
# param resnet.layer1.0.bn3.bias required gradient? -> True
# param resnet.layer1.0.downsample.0.weight required gradient? -> True
# param resnet.layer1.0.downsample.1.weight required gradient? -> True
# param resnet.layer1.0.downsample.1.bias required gradient? -> True
# param resnet.layer1.1.conv1.weight required gradient? -> True
# param resnet.layer1.1.bn1.weight required gradient? -> True
# param resnet.layer1.1.bn1.bias required gradient? -> True
# param resnet.layer1.1.conv2.weight required gradient? -> True
# param resnet.layer1.1.bn2.weight required gradient? -> True
# param resnet.layer1.1.bn2.bias required gradient? -> True
# param resnet.layer1.1.conv3.weight required gradient? -> True
# param resnet.layer1.1.bn3.weight required gradient? -> True
# param resnet.layer1.1.bn3.bias required gradient? -> True
# param resnet.layer1.2.conv1.weight required gradient? -> True
# param resnet.layer1.2.bn1.weight required gradient? -> True
# param resnet.layer1.2.bn1.bias required gradient? -> True
# param resnet.layer1.2.conv2.weight required gradient? -> True
# param resnet.layer1.2.bn2.weight required gradient? -> True
# param resnet.layer1.2.bn2.bias required gradient? -> True
# param resnet.layer1.2.conv3.weight required gradient? -> True
# param resnet.layer1.2.bn3.weight required gradient? -> True
# param resnet.layer1.2.bn3.bias required gradient? -> True
# param resnet.layer2.0.conv1.weight required gradient? -> True
# param resnet.layer2.0.bn1.weight required gradient? -> True
# param resnet.layer2.0.bn1.bias required gradient? -> True
# param resnet.layer2.0.conv2.weight required gradient? -> True
# param resnet.layer2.0.bn2.weight required gradient? -> True
# param resnet.layer2.0.bn2.bias required gradient? -> True
# param resnet.layer2.0.conv3.weight required gradient? -> True
# param resnet.layer2.0.bn3.weight required gradient? -> True
# param resnet.layer2.0.bn3.bias required gradient? -> True
# param resnet.layer2.0.downsample.0.weight required gradient? -> True
# param resnet.layer2.0.downsample.1.weight required gradient? -> True
# param resnet.layer2.0.downsample.1.bias required gradient? -> True
# param resnet.layer2.1.conv1.weight required gradient? -> True
# param resnet.layer2.1.bn1.weight required gradient? -> True
# param resnet.layer2.1.bn1.bias required gradient? -> True
# param resnet.layer2.1.conv2.weight required gradient? -> True
# param resnet.layer2.1.bn2.weight required gradient? -> True
# param resnet.layer2.1.bn2.bias required gradient? -> True
# param resnet.layer2.1.conv3.weight required gradient? -> True
# param resnet.layer2.1.bn3.weight required gradient? -> True
# param resnet.layer2.1.bn3.bias required gradient? -> True
# param resnet.layer2.2.conv1.weight required gradient? -> True
# param resnet.layer2.2.bn1.weight required gradient? -> True
# param resnet.layer2.2.bn1.bias required gradient? -> True
# param resnet.layer2.2.conv2.weight required gradient? -> True
# param resnet.layer2.2.bn2.weight required gradient? -> True
# param resnet.layer2.2.bn2.bias required gradient? -> True
# param resnet.layer2.2.conv3.weight required gradient? -> True
# param resnet.layer2.2.bn3.weight required gradient? -> True
# param resnet.layer2.2.bn3.bias required gradient? -> True
# param resnet.layer2.3.conv1.weight required gradient? -> True
# param resnet.layer2.3.bn1.weight required gradient? -> True
# param resnet.layer2.3.bn1.bias required gradient? -> True
# param resnet.layer2.3.conv2.weight required gradient? -> True
# param resnet.layer2.3.bn2.weight required gradient? -> True
# param resnet.layer2.3.bn2.bias required gradient? -> True
# param resnet.layer2.3.conv3.weight required gradient? -> True
# param resnet.layer2.3.bn3.weight required gradient? -> True
# param resnet.layer2.3.bn3.bias required gradient? -> True
# param resnet.layer2.4.conv1.weight required gradient? -> True
# param resnet.layer2.4.bn1.weight required gradient? -> True
# param resnet.layer2.4.bn1.bias required gradient? -> True
# param resnet.layer2.4.conv2.weight required gradient? -> True
# param resnet.layer2.4.bn2.weight required gradient? -> True
# param resnet.layer2.4.bn2.bias required gradient? -> True
# param resnet.layer2.4.conv3.weight required gradient? -> True
# param resnet.layer2.4.bn3.weight required gradient? -> True
# param resnet.layer2.4.bn3.bias required gradient? -> True
# param resnet.layer2.5.conv1.weight required gradient? -> True
# param resnet.layer2.5.bn1.weight required gradient? -> True
# param resnet.layer2.5.bn1.bias required gradient? -> True
# param resnet.layer2.5.conv2.weight required gradient? -> True
# param resnet.layer2.5.bn2.weight required gradient? -> True
# param resnet.layer2.5.bn2.bias required gradient? -> True
# param resnet.layer2.5.conv3.weight required gradient? -> True
# param resnet.layer2.5.bn3.weight required gradient? -> True
# param resnet.layer2.5.bn3.bias required gradient? -> True
# param resnet.layer2.6.conv1.weight required gradient? -> True
# param resnet.layer2.6.bn1.weight required gradient? -> True
# param resnet.layer2.6.bn1.bias required gradient? -> True
# param resnet.layer2.6.conv2.weight required gradient? -> True
# param resnet.layer2.6.bn2.weight required gradient? -> True
# param resnet.layer2.6.bn2.bias required gradient? -> True
# param resnet.layer2.6.conv3.weight required gradient? -> True
# param resnet.layer2.6.bn3.weight required gradient? -> True
# param resnet.layer2.6.bn3.bias required gradient? -> True
# param resnet.layer2.7.conv1.weight required gradient? -> True
# param resnet.layer2.7.bn1.weight required gradient? -> True
# param resnet.layer2.7.bn1.bias required gradient? -> True
# param resnet.layer2.7.conv2.weight required gradient? -> True
# param resnet.layer2.7.bn2.weight required gradient? -> True
# param resnet.layer2.7.bn2.bias required gradient? -> True
# param resnet.layer2.7.conv3.weight required gradient? -> True
# param resnet.layer2.7.bn3.weight required gradient? -> True
# param resnet.layer2.7.bn3.bias required gradient? -> True
# param resnet.layer3.0.conv1.weight required gradient? -> True
# param resnet.layer3.0.bn1.weight required gradient? -> True
# param resnet.layer3.0.bn1.bias required gradient? -> True
# param resnet.layer3.0.conv2.weight required gradient? -> True
# param resnet.layer3.0.bn2.weight required gradient? -> True
# param resnet.layer3.0.bn2.bias required gradient? -> True
# param resnet.layer3.0.conv3.weight required gradient? -> True
# param resnet.layer3.0.bn3.weight required gradient? -> True
# param resnet.layer3.0.bn3.bias required gradient? -> True
# param resnet.layer3.0.downsample.0.weight required gradient? -> True
# param resnet.layer3.0.downsample.1.weight required gradient? -> True
# param resnet.layer3.0.downsample.1.bias required gradient? -> True
# param resnet.layer3.1.conv1.weight required gradient? -> True
# param resnet.layer3.1.bn1.weight required gradient? -> True
# param resnet.layer3.1.bn1.bias required gradient? -> True
# param resnet.layer3.1.conv2.weight required gradient? -> True
# param resnet.layer3.1.bn2.weight required gradient? -> True
# param resnet.layer3.1.bn2.bias required gradient? -> True
# param resnet.layer3.1.conv3.weight required gradient? -> True
# param resnet.layer3.1.bn3.weight required gradient? -> True
# param resnet.layer3.1.bn3.bias required gradient? -> True
# param resnet.layer3.2.conv1.weight required gradient? -> True
# param resnet.layer3.2.bn1.weight required gradient? -> True
# param resnet.layer3.2.bn1.bias required gradient? -> True
# param resnet.layer3.2.conv2.weight required gradient? -> True
# param resnet.layer3.2.bn2.weight required gradient? -> True
# param resnet.layer3.2.bn2.bias required gradient? -> True
# param resnet.layer3.2.conv3.weight required gradient? -> True
# param resnet.layer3.2.bn3.weight required gradient? -> True
# param resnet.layer3.2.bn3.bias required gradient? -> True
# param resnet.layer3.3.conv1.weight required gradient? -> True
# param resnet.layer3.3.bn1.weight required gradient? -> True
# param resnet.layer3.3.bn1.bias required gradient? -> True
# param resnet.layer3.3.conv2.weight required gradient? -> True
# param resnet.layer3.3.bn2.weight required gradient? -> True
# param resnet.layer3.3.bn2.bias required gradient? -> True
# param resnet.layer3.3.conv3.weight required gradient? -> True
# param resnet.layer3.3.bn3.weight required gradient? -> True
# param resnet.layer3.3.bn3.bias required gradient? -> True
# param resnet.layer3.4.conv1.weight required gradient? -> True
# param resnet.layer3.4.bn1.weight required gradient? -> True
# param resnet.layer3.4.bn1.bias required gradient? -> True
# param resnet.layer3.4.conv2.weight required gradient? -> True
# param resnet.layer3.4.bn2.weight required gradient? -> True
# param resnet.layer3.4.bn2.bias required gradient? -> True
# param resnet.layer3.4.conv3.weight required gradient? -> True
# param resnet.layer3.4.bn3.weight required gradient? -> True
# param resnet.layer3.4.bn3.bias required gradient? -> True
# param resnet.layer3.5.conv1.weight required gradient? -> True
# param resnet.layer3.5.bn1.weight required gradient? -> True
# param resnet.layer3.5.bn1.bias required gradient? -> True
# param resnet.layer3.5.conv2.weight required gradient? -> True
# param resnet.layer3.5.bn2.weight required gradient? -> True
# param resnet.layer3.5.bn2.bias required gradient? -> True
# param resnet.layer3.5.conv3.weight required gradient? -> True
# param resnet.layer3.5.bn3.weight required gradient? -> True
# param resnet.layer3.5.bn3.bias required gradient? -> True
# param resnet.layer3.6.conv1.weight required gradient? -> True
# param resnet.layer3.6.bn1.weight required gradient? -> True
# param resnet.layer3.6.bn1.bias required gradient? -> True
# param resnet.layer3.6.conv2.weight required gradient? -> True
# param resnet.layer3.6.bn2.weight required gradient? -> True
# param resnet.layer3.6.bn2.bias required gradient? -> True
# param resnet.layer3.6.conv3.weight required gradient? -> True
# param resnet.layer3.6.bn3.weight required gradient? -> True
# param resnet.layer3.6.bn3.bias required gradient? -> True
# param resnet.layer3.7.conv1.weight required gradient? -> True
# param resnet.layer3.7.bn1.weight required gradient? -> True
# param resnet.layer3.7.bn1.bias required gradient? -> True
# param resnet.layer3.7.conv2.weight required gradient? -> True
# param resnet.layer3.7.bn2.weight required gradient? -> True
# param resnet.layer3.7.bn2.bias required gradient? -> True
# param resnet.layer3.7.conv3.weight required gradient? -> True
# param resnet.layer3.7.bn3.weight required gradient? -> True
# param resnet.layer3.7.bn3.bias required gradient? -> True
# param resnet.layer3.8.conv1.weight required gradient? -> True
# param resnet.layer3.8.bn1.weight required gradient? -> True
# param resnet.layer3.8.bn1.bias required gradient? -> True
# param resnet.layer3.8.conv2.weight required gradient? -> True
# param resnet.layer3.8.bn2.weight required gradient? -> True
# param resnet.layer3.8.bn2.bias required gradient? -> True
# param resnet.layer3.8.conv3.weight required gradient? -> True
# param resnet.layer3.8.bn3.weight required gradient? -> True
# param resnet.layer3.8.bn3.bias required gradient? -> True
# param resnet.layer3.9.conv1.weight required gradient? -> True
# param resnet.layer3.9.bn1.weight required gradient? -> True
# param resnet.layer3.9.bn1.bias required gradient? -> True
# param resnet.layer3.9.conv2.weight required gradient? -> True
# param resnet.layer3.9.bn2.weight required gradient? -> True
# param resnet.layer3.9.bn2.bias required gradient? -> True
# param resnet.layer3.9.conv3.weight required gradient? -> True
# param resnet.layer3.9.bn3.weight required gradient? -> True
# param resnet.layer3.9.bn3.bias required gradient? -> True
# param resnet.layer3.10.conv1.weight required gradient? -> True
# param resnet.layer3.10.bn1.weight required gradient? -> True
# param resnet.layer3.10.bn1.bias required gradient? -> True
# param resnet.layer3.10.conv2.weight required gradient? -> True
# param resnet.layer3.10.bn2.weight required gradient? -> True
# param resnet.layer3.10.bn2.bias required gradient? -> True
# param resnet.layer3.10.conv3.weight required gradient? -> True
# param resnet.layer3.10.bn3.weight required gradient? -> True
# param resnet.layer3.10.bn3.bias required gradient? -> True
# param resnet.layer3.11.conv1.weight required gradient? -> True
# param resnet.layer3.11.bn1.weight required gradient? -> True
# param resnet.layer3.11.bn1.bias required gradient? -> True
# param resnet.layer3.11.conv2.weight required gradient? -> True
# param resnet.layer3.11.bn2.weight required gradient? -> True
# param resnet.layer3.11.bn2.bias required gradient? -> True
# param resnet.layer3.11.conv3.weight required gradient? -> True
# param resnet.layer3.11.bn3.weight required gradient? -> True
# param resnet.layer3.11.bn3.bias required gradient? -> True
# param resnet.layer3.12.conv1.weight required gradient? -> True
# param resnet.layer3.12.bn1.weight required gradient? -> True
# param resnet.layer3.12.bn1.bias required gradient? -> True
# param resnet.layer3.12.conv2.weight required gradient? -> True
# param resnet.layer3.12.bn2.weight required gradient? -> True
# param resnet.layer3.12.bn2.bias required gradient? -> True
# param resnet.layer3.12.conv3.weight required gradient? -> True
# param resnet.layer3.12.bn3.weight required gradient? -> True
# param resnet.layer3.12.bn3.bias required gradient? -> True
# param resnet.layer3.13.conv1.weight required gradient? -> True
# param resnet.layer3.13.bn1.weight required gradient? -> True
# param resnet.layer3.13.bn1.bias required gradient? -> True
# param resnet.layer3.13.conv2.weight required gradient? -> True
# param resnet.layer3.13.bn2.weight required gradient? -> True
# param resnet.layer3.13.bn2.bias required gradient? -> True
# param resnet.layer3.13.conv3.weight required gradient? -> True
# param resnet.layer3.13.bn3.weight required gradient? -> True
# param resnet.layer3.13.bn3.bias required gradient? -> True
# param resnet.layer3.14.conv1.weight required gradient? -> True
# param resnet.layer3.14.bn1.weight required gradient? -> True
# param resnet.layer3.14.bn1.bias required gradient? -> True
# param resnet.layer3.14.conv2.weight required gradient? -> True
# param resnet.layer3.14.bn2.weight required gradient? -> True
# param resnet.layer3.14.bn2.bias required gradient? -> True
# param resnet.layer3.14.conv3.weight required gradient? -> True
# param resnet.layer3.14.bn3.weight required gradient? -> True
# param resnet.layer3.14.bn3.bias required gradient? -> True
# param resnet.layer3.15.conv1.weight required gradient? -> True
# param resnet.layer3.15.bn1.weight required gradient? -> True
# param resnet.layer3.15.bn1.bias required gradient? -> True
# param resnet.layer3.15.conv2.weight required gradient? -> True
# param resnet.layer3.15.bn2.weight required gradient? -> True
# param resnet.layer3.15.bn2.bias required gradient? -> True
# param resnet.layer3.15.conv3.weight required gradient? -> True
# param resnet.layer3.15.bn3.weight required gradient? -> True
# param resnet.layer3.15.bn3.bias required gradient? -> True
# param resnet.layer3.16.conv1.weight required gradient? -> True
# param resnet.layer3.16.bn1.weight required gradient? -> True
# param resnet.layer3.16.bn1.bias required gradient? -> True
# param resnet.layer3.16.conv2.weight required gradient? -> True
# param resnet.layer3.16.bn2.weight required gradient? -> True
# param resnet.layer3.16.bn2.bias required gradient? -> True
# param resnet.layer3.16.conv3.weight required gradient? -> True
# param resnet.layer3.16.bn3.weight required gradient? -> True
# param resnet.layer3.16.bn3.bias required gradient? -> True
# param resnet.layer3.17.conv1.weight required gradient? -> True
# param resnet.layer3.17.bn1.weight required gradient? -> True
# param resnet.layer3.17.bn1.bias required gradient? -> True
# param resnet.layer3.17.conv2.weight required gradient? -> True
# param resnet.layer3.17.bn2.weight required gradient? -> True
# param resnet.layer3.17.bn2.bias required gradient? -> True
# param resnet.layer3.17.conv3.weight required gradient? -> True
# param resnet.layer3.17.bn3.weight required gradient? -> True
# param resnet.layer3.17.bn3.bias required gradient? -> True
# param resnet.layer3.18.conv1.weight required gradient? -> True
# param resnet.layer3.18.bn1.weight required gradient? -> True
# param resnet.layer3.18.bn1.bias required gradient? -> True
# param resnet.layer3.18.conv2.weight required gradient? -> True
# param resnet.layer3.18.bn2.weight required gradient? -> True
# param resnet.layer3.18.bn2.bias required gradient? -> True
# param resnet.layer3.18.conv3.weight required gradient? -> True
# param resnet.layer3.18.bn3.weight required gradient? -> True
# param resnet.layer3.18.bn3.bias required gradient? -> True
# param resnet.layer3.19.conv1.weight required gradient? -> True
# param resnet.layer3.19.bn1.weight required gradient? -> True
# param resnet.layer3.19.bn1.bias required gradient? -> True
# param resnet.layer3.19.conv2.weight required gradient? -> True
# param resnet.layer3.19.bn2.weight required gradient? -> True
# param resnet.layer3.19.bn2.bias required gradient? -> True
# param resnet.layer3.19.conv3.weight required gradient? -> True
# param resnet.layer3.19.bn3.weight required gradient? -> True
# param resnet.layer3.19.bn3.bias required gradient? -> True
# param resnet.layer3.20.conv1.weight required gradient? -> True
# param resnet.layer3.20.bn1.weight required gradient? -> True
# param resnet.layer3.20.bn1.bias required gradient? -> True
# param resnet.layer3.20.conv2.weight required gradient? -> True
# param resnet.layer3.20.bn2.weight required gradient? -> True
# param resnet.layer3.20.bn2.bias required gradient? -> True
# param resnet.layer3.20.conv3.weight required gradient? -> True
# param resnet.layer3.20.bn3.weight required gradient? -> True
# param resnet.layer3.20.bn3.bias required gradient? -> True
# param resnet.layer3.21.conv1.weight required gradient? -> True
# param resnet.layer3.21.bn1.weight required gradient? -> True
# param resnet.layer3.21.bn1.bias required gradient? -> True
# param resnet.layer3.21.conv2.weight required gradient? -> True
# param resnet.layer3.21.bn2.weight required gradient? -> True
# param resnet.layer3.21.bn2.bias required gradient? -> True
# param resnet.layer3.21.conv3.weight required gradient? -> True
# param resnet.layer3.21.bn3.weight required gradient? -> True
# param resnet.layer3.21.bn3.bias required gradient? -> True
# param resnet.layer3.22.conv1.weight required gradient? -> True
# param resnet.layer3.22.bn1.weight required gradient? -> True
# param resnet.layer3.22.bn1.bias required gradient? -> True
# param resnet.layer3.22.conv2.weight required gradient? -> True
# param resnet.layer3.22.bn2.weight required gradient? -> True
# param resnet.layer3.22.bn2.bias required gradient? -> True
# param resnet.layer3.22.conv3.weight required gradient? -> True
# param resnet.layer3.22.bn3.weight required gradient? -> True
# param resnet.layer3.22.bn3.bias required gradient? -> True
# param resnet.layer3.23.conv1.weight required gradient? -> True
# param resnet.layer3.23.bn1.weight required gradient? -> True
# param resnet.layer3.23.bn1.bias required gradient? -> True
# param resnet.layer3.23.conv2.weight required gradient? -> True
# param resnet.layer3.23.bn2.weight required gradient? -> True
# param resnet.layer3.23.bn2.bias required gradient? -> True
# param resnet.layer3.23.conv3.weight required gradient? -> True
# param resnet.layer3.23.bn3.weight required gradient? -> True
# param resnet.layer3.23.bn3.bias required gradient? -> True
# param resnet.layer3.24.conv1.weight required gradient? -> True
# param resnet.layer3.24.bn1.weight required gradient? -> True
# param resnet.layer3.24.bn1.bias required gradient? -> True
# param resnet.layer3.24.conv2.weight required gradient? -> True
# param resnet.layer3.24.bn2.weight required gradient? -> True
# param resnet.layer3.24.bn2.bias required gradient? -> True
# param resnet.layer3.24.conv3.weight required gradient? -> True
# param resnet.layer3.24.bn3.weight required gradient? -> True
# param resnet.layer3.24.bn3.bias required gradient? -> True
# param resnet.layer3.25.conv1.weight required gradient? -> True
# param resnet.layer3.25.bn1.weight required gradient? -> True
# param resnet.layer3.25.bn1.bias required gradient? -> True
# param resnet.layer3.25.conv2.weight required gradient? -> True
# param resnet.layer3.25.bn2.weight required gradient? -> True
# param resnet.layer3.25.bn2.bias required gradient? -> True
# param resnet.layer3.25.conv3.weight required gradient? -> True
# param resnet.layer3.25.bn3.weight required gradient? -> True
# param resnet.layer3.25.bn3.bias required gradient? -> True
# param resnet.layer3.26.conv1.weight required gradient? -> True
# param resnet.layer3.26.bn1.weight required gradient? -> True
# param resnet.layer3.26.bn1.bias required gradient? -> True
# param resnet.layer3.26.conv2.weight required gradient? -> True
# param resnet.layer3.26.bn2.weight required gradient? -> True
# param resnet.layer3.26.bn2.bias required gradient? -> True
# param resnet.layer3.26.conv3.weight required gradient? -> True
# param resnet.layer3.26.bn3.weight required gradient? -> True
# param resnet.layer3.26.bn3.bias required gradient? -> True
# param resnet.layer3.27.conv1.weight required gradient? -> True
# param resnet.layer3.27.bn1.weight required gradient? -> True
# param resnet.layer3.27.bn1.bias required gradient? -> True
# param resnet.layer3.27.conv2.weight required gradient? -> True
# param resnet.layer3.27.bn2.weight required gradient? -> True
# param resnet.layer3.27.bn2.bias required gradient? -> True
# param resnet.layer3.27.conv3.weight required gradient? -> True
# param resnet.layer3.27.bn3.weight required gradient? -> True
# param resnet.layer3.27.bn3.bias required gradient? -> True
# param resnet.layer3.28.conv1.weight required gradient? -> True
# param resnet.layer3.28.bn1.weight required gradient? -> True
# param resnet.layer3.28.bn1.bias required gradient? -> True
# param resnet.layer3.28.conv2.weight required gradient? -> True
# param resnet.layer3.28.bn2.weight required gradient? -> True
# param resnet.layer3.28.bn2.bias required gradient? -> True
# param resnet.layer3.28.conv3.weight required gradient? -> True
# param resnet.layer3.28.bn3.weight required gradient? -> True
# param resnet.layer3.28.bn3.bias required gradient? -> True
# param resnet.layer3.29.conv1.weight required gradient? -> True
# param resnet.layer3.29.bn1.weight required gradient? -> True
# param resnet.layer3.29.bn1.bias required gradient? -> True
# param resnet.layer3.29.conv2.weight required gradient? -> True
# param resnet.layer3.29.bn2.weight required gradient? -> True
# param resnet.layer3.29.bn2.bias required gradient? -> True
# param resnet.layer3.29.conv3.weight required gradient? -> True
# param resnet.layer3.29.bn3.weight required gradient? -> True
# param resnet.layer3.29.bn3.bias required gradient? -> True
# param resnet.layer3.30.conv1.weight required gradient? -> True
# param resnet.layer3.30.bn1.weight required gradient? -> True
# param resnet.layer3.30.bn1.bias required gradient? -> True
# param resnet.layer3.30.conv2.weight required gradient? -> True
# param resnet.layer3.30.bn2.weight required gradient? -> True
# param resnet.layer3.30.bn2.bias required gradient? -> True
# param resnet.layer3.30.conv3.weight required gradient? -> True
# param resnet.layer3.30.bn3.weight required gradient? -> True
# param resnet.layer3.30.bn3.bias required gradient? -> True
# param resnet.layer3.31.conv1.weight required gradient? -> True
# param resnet.layer3.31.bn1.weight required gradient? -> True
# param resnet.layer3.31.bn1.bias required gradient? -> True
# param resnet.layer3.31.conv2.weight required gradient? -> True
# param resnet.layer3.31.bn2.weight required gradient? -> True
# param resnet.layer3.31.bn2.bias required gradient? -> True
# param resnet.layer3.31.conv3.weight required gradient? -> True
# param resnet.layer3.31.bn3.weight required gradient? -> True
# param resnet.layer3.31.bn3.bias required gradient? -> True
# param resnet.layer3.32.conv1.weight required gradient? -> True
# param resnet.layer3.32.bn1.weight required gradient? -> True
# param resnet.layer3.32.bn1.bias required gradient? -> True
# param resnet.layer3.32.conv2.weight required gradient? -> True
# param resnet.layer3.32.bn2.weight required gradient? -> True
# param resnet.layer3.32.bn2.bias required gradient? -> True
# param resnet.layer3.32.conv3.weight required gradient? -> True
# param resnet.layer3.32.bn3.weight required gradient? -> True
# param resnet.layer3.32.bn3.bias required gradient? -> True
# param resnet.layer3.33.conv1.weight required gradient? -> True
# param resnet.layer3.33.bn1.weight required gradient? -> True
# param resnet.layer3.33.bn1.bias required gradient? -> True
# param resnet.layer3.33.conv2.weight required gradient? -> True
# param resnet.layer3.33.bn2.weight required gradient? -> True
# param resnet.layer3.33.bn2.bias required gradient? -> True
# param resnet.layer3.33.conv3.weight required gradient? -> True
# param resnet.layer3.33.bn3.weight required gradient? -> True
# param resnet.layer3.33.bn3.bias required gradient? -> True
# param resnet.layer3.34.conv1.weight required gradient? -> True
# param resnet.layer3.34.bn1.weight required gradient? -> True
# param resnet.layer3.34.bn1.bias required gradient? -> True
# param resnet.layer3.34.conv2.weight required gradient? -> True
# param resnet.layer3.34.bn2.weight required gradient? -> True
# param resnet.layer3.34.bn2.bias required gradient? -> True
# param resnet.layer3.34.conv3.weight required gradient? -> True
# param resnet.layer3.34.bn3.weight required gradient? -> True
# param resnet.layer3.34.bn3.bias required gradient? -> True
# param resnet.layer3.35.conv1.weight required gradient? -> True
# param resnet.layer3.35.bn1.weight required gradient? -> True
# param resnet.layer3.35.bn1.bias required gradient? -> True
# param resnet.layer3.35.conv2.weight required gradient? -> True
# param resnet.layer3.35.bn2.weight required gradient? -> True
# param resnet.layer3.35.bn2.bias required gradient? -> True
# param resnet.layer3.35.conv3.weight required gradient? -> True
# param resnet.layer3.35.bn3.weight required gradient? -> True
# param resnet.layer3.35.bn3.bias required gradient? -> True
# param resnet.layer4.0.conv1.weight required gradient? -> True
# param resnet.layer4.0.bn1.weight required gradient? -> True
# param resnet.layer4.0.bn1.bias required gradient? -> True
# param resnet.layer4.0.conv2.weight required gradient? -> True
# param resnet.layer4.0.bn2.weight required gradient? -> True
# param resnet.layer4.0.bn2.bias required gradient? -> True
# param resnet.layer4.0.conv3.weight required gradient? -> True
# param resnet.layer4.0.bn3.weight required gradient? -> True
# param resnet.layer4.0.bn3.bias required gradient? -> True
# param resnet.layer4.0.downsample.0.weight required gradient? -> True
# param resnet.layer4.0.downsample.1.weight required gradient? -> True
# param resnet.layer4.0.downsample.1.bias required gradient? -> True
# param resnet.layer4.1.conv1.weight required gradient? -> True
# param resnet.layer4.1.bn1.weight required gradient? -> True
# param resnet.layer4.1.bn1.bias required gradient? -> True
# param resnet.layer4.1.conv2.weight required gradient? -> True
# param resnet.layer4.1.bn2.weight required gradient? -> True
# param resnet.layer4.1.bn2.bias required gradient? -> True
# param resnet.layer4.1.conv3.weight required gradient? -> True
# param resnet.layer4.1.bn3.weight required gradient? -> True
# param resnet.layer4.1.bn3.bias required gradient? -> True
# param resnet.layer4.2.conv1.weight required gradient? -> True
# param resnet.layer4.2.bn1.weight required gradient? -> True
# param resnet.layer4.2.bn1.bias required gradient? -> True
# param resnet.layer4.2.conv2.weight required gradient? -> True
# param resnet.layer4.2.bn2.weight required gradient? -> True
# param resnet.layer4.2.bn2.bias required gradient? -> True
# param resnet.layer4.2.conv3.weight required gradient? -> True
# param resnet.layer4.2.bn3.weight required gradient? -> True
# param resnet.layer4.2.bn3.bias required gradient? -> True
# param resnet.fc.0.weight   required gradient? -> True
# param resnet.fc.0.bias     required gradient? -> True
# param lstm.weight_ih_l0    required gradient? -> True
# param lstm.weight_hh_l0    required gradient? -> True
# param lstm.bias_ih_l0      required gradient? -> True
# param lstm.bias_hh_l0      required gradient? -> True
# param lstm.weight_ih_l1    required gradient? -> True
# param lstm.weight_hh_l1    required gradient? -> True
# param lstm.bias_ih_l1      required gradient? -> True
# param lstm.bias_hh_l1      required gradient? -> True
# param lstm.weight_ih_l2    required gradient? -> True
# param lstm.weight_hh_l2    required gradient? -> True
# param lstm.bias_ih_l2      required gradient? -> True
# param lstm.bias_hh_l2      required gradient? -> True
# param lstm.weight_ih_l3    required gradient? -> True
# param lstm.weight_hh_l3    required gradient? -> True
# param lstm.bias_ih_l3      required gradient? -> True
# param lstm.bias_hh_l3      required gradient? -> True
# param lstm.weight_ih_l4    required gradient? -> True
# param lstm.weight_hh_l4    required gradient? -> True
# param lstm.bias_ih_l4      required gradient? -> True
# param lstm.bias_hh_l4      required gradient? -> True
# param fc_1.weight          required gradient? -> True
# param fc_1.bias            required gradient? -> True
# param fc_2.weight          required gradient? -> True
# param fc_2.bias            required gradient? -> True

# %% [markdown]
# # Loss, Optimizer, Scheduler 설정

# %%
# criterion = nn.CrossEntropyLoss()
# criterion = nn.BCEWithLogitsLoss()
criterion = nn.BCELoss()
optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=5e-4)
scheduler = StepLR(optimizer, 5, gamma=0.5)

# %%
a = 0
for i in loader:
  a = i
  break
  
inputs, labels = a
print(inputs.shape)
print(labels.shape)
# batch, seq, channel, width, height
# batch, seq, label
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# torch.Size([4, 5, 3, 224, 224])
# torch.Size([4, 5, 6])

# %% [markdown]
# # 데이터로더, 모델 인풋, 아웃풋 점검

# %%
from torchvision.transforms import ToPILImage
from IPython.display import Image
to_img = ToPILImage()

display(to_img(inputs[0][0]))
display(to_img(inputs[0][1]))

inputs = inputs.to(device)
labels = labels.to(device)
outs = model(inputs)
print(outs.shape)
# print(outs > 0.5)
print((((outs > 0.5) == labels).sum(axis=1) == 6).sum())
loss = criterion(outs, labels)
print(labels.shape)
print(loss.cpu())
print(((labels == (outs > 0.5)).sum(axis=2) == 6).sum())
# print(outs > 0.5)
# print(labels)
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FDC7CF7CD10>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FDC743569D0>
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# torch.Size([4, 5, 6])
# tensor(0, device='cuda:0')
# torch.Size([4, 5, 6])
# tensor(0.6894, grad_fn=<CopyBackwards>)
# tensor(0, device='cuda:0')

# %% [markdown]
# # 학습 진행상황 확인을 위한 wandb 설정

# %%
# !pip install wandb
# Out:
# Requirement already satisfied: wandb in /usr/local/lib/python3.7/dist-packages (0.10.32)
# Requirement already satisfied: subprocess32>=3.5.3 in /usr/local/lib/python3.7/dist-packages (from wandb) (3.5.4)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from wandb) (3.13)
# Requirement already satisfied: sentry-sdk>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (1.1.0)
# Requirement already satisfied: promise<3,>=2.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.3)
# Requirement already satisfied: six>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (1.15.0)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (0.4.0)
# Requirement already satisfied: pathtools in /usr/local/lib/python3.7/dist-packages (from wandb) (0.1.2)
# Requirement already satisfied: protobuf>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (3.12.4)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.23.0)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.8.1)
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (7.1.2)
# Requirement already satisfied: configparser>=3.8.1 in /usr/local/lib/python3.7/dist-packages (from wandb) (5.0.2)
# Requirement already satisfied: shortuuid>=0.5.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (1.0.1)
# Requirement already satisfied: GitPython>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (3.1.18)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (5.4.8)
# Requirement already satisfied: urllib3>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from sentry-sdk>=0.4.0->wandb) (1.24.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from sentry-sdk>=0.4.0->wandb) (2021.5.30)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from protobuf>=3.12.0->wandb) (57.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (3.0.4)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.7/dist-packages (from GitPython>=1.0.0->wandb) (4.0.7)
# Requirement already satisfied: typing-extensions>=3.7.4.0; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from GitPython>=1.0.0->wandb) (3.7.4.3)
# Requirement already satisfied: smmap<5,>=3.0.1 in /usr/local/lib/python3.7/dist-packages (from gitdb<5,>=4.0.1->GitPython>=1.0.0->wandb) (4.0.0)

# %%
import wandb

wandb.login()
# Out:
# wandb: Currently logged in as: junhyeokk (use `wandb login --relogin` to force relogin)
# True

# %%
config = {}
config['n_epochs'] = num_epochs
config['batch_sze'] = batch_size
# config['lr'] = lr


wandb.init(project="boomhill24_2", config=config)
# Out:
#                 Tracking run with wandb version 0.10.32<br/>
#                 Syncing run <strong style="color:#cdcd00">olive-cherry-10</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/junhyeokk/boomhill24_2" target="_blank">https://wandb.ai/junhyeokk/boomhill24_2</a><br/>
#                 Run page: <a href="https://wandb.ai/junhyeokk/boomhill24_2/runs/1zb7beat" target="_blank">https://wandb.ai/junhyeokk/boomhill24_2/runs/1zb7beat</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210626_061324-1zb7beat</code><br/><br/>
# <h1>Run(1zb7beat)</h1><iframe src="https://wandb.ai/junhyeokk/boomhill24_2/runs/1zb7beat" style="border:none;width:100%;height:400px"></iframe>

# %% [markdown]
# # 학습 진행 및 저장

# %%
for epoch in range(num_epochs):
  model.train()
  loss_value = 0
  matches = 0
  
  for idx, train_batch in enumerate(loader):
    inputs, labels = train_batch
    inputs = inputs.to(device)
    labels = labels.to(device)

    outs = model(inputs)
    preds = (outs > 0.5)
    loss = criterion(outs, labels)

    loss.backward()
    optimizer.step()
    optimizer.zero_grad()

    loss_value += loss.item()
    # matches += (preds == labels).sum().item()
    matches += ((preds == labels).sum(axis = 2) == 6).sum()

    if (idx + 1) % log_interval == 0:
      train_loss = loss_value / log_interval
      train_acc = matches / seq_size / batch_size / log_interval
      current_lr = scheduler.get_last_lr()

      wandb.log({"epoch" : epoch, "training_loss" : train_loss, "training_acc" : train_acc, "lr" : current_lr})
      print(
          f"Epoch[{epoch}/{num_epochs}]({idx + 1}/{len(loader)}) || "
          # f"training loss {train_loss:4.4} || lr {current_lr}"
          f"training loss {train_loss:4.4} || training accuracy {train_acc:4.2%} || lr {current_lr}"
      )

      loss_value = 0
      matches = 0

    scheduler.step()
    
  torch.save(model.state_dict(), save_path)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Epoch[0/20](10/244) || training loss 0.6865 || training accuracy 22.50% || lr [5e-05]
# Epoch[0/20](20/244) || training loss 0.695 || training accuracy 0.00% || lr [1.25e-05]
# Epoch[0/20](30/244) || training loss 0.6925 || training accuracy 0.00% || lr [3.125e-06]
# Epoch[0/20](40/244) || training loss 0.6934 || training accuracy 0.00% || lr [7.8125e-07]
# Epoch[0/20](50/244) || training loss 0.6929 || training accuracy 0.00% || lr [1.953125e-07]
# Epoch[0/20](60/244) || training loss 0.6931 || training accuracy 0.00% || lr [4.8828125e-08]
# Epoch[0/20](70/244) || training loss 0.6931 || training accuracy 0.00% || lr [1.220703125e-08]
# Epoch[0/20](80/244) || training loss 0.6935 || training accuracy 0.00% || lr [3.0517578125e-09]
# Epoch[0/20](90/244) || training loss 0.6931 || training accuracy 0.00% || lr [7.62939453125e-10]
# Epoch[0/20](100/244) || training loss 0.6931 || training accuracy 0.00% || lr [1.9073486328125e-10]
# Epoch[0/20](110/244) || training loss 0.6926 || training accuracy 0.00% || lr [4.76837158203125e-11]
# Epoch[0/20](120/244) || training loss 0.6914 || training accuracy 0.00% || lr [1.1920928955078126e-11]
# Epoch[0/20](130/244) || training loss 0.6909 || training accuracy 0.00% || lr [2.9802322387695314e-12]
# Epoch[0/20](140/244) || training loss 0.6929 || training accuracy 0.00% || lr [7.450580596923828e-13]
# Epoch[0/20](150/244) || training loss 0.6924 || training accuracy 0.00% || lr [1.862645149230957e-13]
# Epoch[0/20](160/244) || training loss 0.6934 || training accuracy 2.50% || lr [4.656612873077393e-14]
# Epoch[0/20](170/244) || training loss 0.6915 || training accuracy 2.50% || lr [1.1641532182693482e-14]
# Epoch[0/20](180/244) || training loss 0.6929 || training accuracy 0.00% || lr [2.9103830456733705e-15]
# Epoch[0/20](190/244) || training loss 0.6972 || training accuracy 0.00% || lr [7.275957614183426e-16]
# Epoch[0/20](200/244) || training loss 0.6918 || training accuracy 0.00% || lr [1.8189894035458566e-16]
# Epoch[0/20](210/244) || training loss 0.6928 || training accuracy 0.00% || lr [4.5474735088646414e-17]
# Epoch[0/20](220/244) || training loss 0.6928 || training accuracy 0.00% || lr [1.1368683772161604e-17]
# Epoch[0/20](230/244) || training loss 0.6925 || training accuracy 0.00% || lr [2.842170943040401e-18]
# Epoch[0/20](240/244) || training loss 0.692 || training accuracy 2.50% || lr [7.105427357601002e-19]
# Epoch[1/20](10/244) || training loss 0.6805 || training accuracy 77.50% || lr [8.881784197001253e-20]
# Epoch[1/20](20/244) || training loss 0.694 || training accuracy 0.00% || lr [2.2204460492503132e-20]
# Epoch[1/20](30/244) || training loss 0.6922 || training accuracy 0.00% || lr [5.551115123125783e-21]
# Epoch[1/20](40/244) || training loss 0.6933 || training accuracy 0.00% || lr [1.3877787807814457e-21]
# Epoch[1/20](50/244) || training loss 0.6929 || training accuracy 0.00% || lr [3.4694469519536144e-22]
# Epoch[1/20](60/244) || training loss 0.6931 || training accuracy 0.00% || lr [8.673617379884036e-23]
# Epoch[1/20](70/244) || training loss 0.6931 || training accuracy 0.00% || lr [2.168404344971009e-23]
# Epoch[1/20](80/244) || training loss 0.6935 || training accuracy 0.00% || lr [5.4210108624275224e-24]
# Epoch[1/20](90/244) || training loss 0.6931 || training accuracy 0.00% || lr [1.3552527156068806e-24]
# Epoch[1/20](100/244) || training loss 0.6931 || training accuracy 0.00% || lr [3.3881317890172015e-25]
# Epoch[1/20](110/244) || training loss 0.6926 || training accuracy 0.00% || lr [8.470329472543004e-26]
# Epoch[1/20](120/244) || training loss 0.6914 || training accuracy 0.00% || lr [2.117582368135751e-26]
# Epoch[1/20](130/244) || training loss 0.6909 || training accuracy 0.00% || lr [5.2939559203393774e-27]
# Epoch[1/20](140/244) || training loss 0.6929 || training accuracy 0.00% || lr [1.3234889800848443e-27]
# Epoch[1/20](150/244) || training loss 0.6924 || training accuracy 0.00% || lr [3.308722450212111e-28]
# Epoch[1/20](160/244) || training loss 0.6934 || training accuracy 2.50% || lr [8.271806125530277e-29]
# Epoch[1/20](170/244) || training loss 0.6915 || training accuracy 2.50% || lr [2.0679515313825693e-29]
# Epoch[1/20](180/244) || training loss 0.6929 || training accuracy 0.00% || lr [5.169878828456423e-30]
# Epoch[1/20](190/244) || training loss 0.6972 || training accuracy 0.00% || lr [1.2924697071141058e-30]
# Epoch[1/20](200/244) || training loss 0.6918 || training accuracy 0.00% || lr [3.2311742677852645e-31]
# Epoch[1/20](210/244) || training loss 0.6928 || training accuracy 0.00% || lr [8.077935669463161e-32]
# Epoch[1/20](220/244) || training loss 0.6928 || training accuracy 0.00% || lr [2.0194839173657903e-32]
# Epoch[1/20](230/244) || training loss 0.6925 || training accuracy 0.00% || lr [5.048709793414476e-33]
# Epoch[1/20](240/244) || training loss 0.692 || training accuracy 2.50% || lr [1.262177448353619e-33]
# Epoch[2/20](10/244) || training loss 0.6805 || training accuracy 77.50% || lr [1.5777218104420237e-34]
# Epoch[2/20](20/244) || training loss 0.694 || training accuracy 0.00% || lr [3.944304526105059e-35]
# Epoch[2/20](30/244) || training loss 0.6922 || training accuracy 0.00% || lr [9.860761315262648e-36]
# Epoch[2/20](40/244) || training loss 0.6933 || training accuracy 0.00% || lr [2.465190328815662e-36]
# Epoch[2/20](50/244) || training loss 0.6929 || training accuracy 0.00% || lr [6.162975822039155e-37]
# Epoch[2/20](60/244) || training loss 0.6931 || training accuracy 0.00% || lr [1.5407439555097888e-37]
# Epoch[2/20](70/244) || training loss 0.6931 || training accuracy 0.00% || lr [3.851859888774472e-38]
# Epoch[2/20](80/244) || training loss 0.6935 || training accuracy 0.00% || lr [9.62964972193618e-39]
# Epoch[2/20](90/244) || training loss 0.6931 || training accuracy 0.00% || lr [2.407412430484045e-39]
# Epoch[2/20](100/244) || training loss 0.6931 || training accuracy 0.00% || lr [6.018531076210112e-40]
# Epoch[2/20](110/244) || training loss 0.6926 || training accuracy 0.00% || lr [1.504632769052528e-40]
# Epoch[2/20](120/244) || training loss 0.6914 || training accuracy 0.00% || lr [3.76158192263132e-41]
# Epoch[2/20](130/244) || training loss 0.6909 || training accuracy 0.00% || lr [9.4039548065783e-42]
# Epoch[2/20](140/244) || training loss 0.6929 || training accuracy 0.00% || lr [2.350988701644575e-42]
# Epoch[2/20](150/244) || training loss 0.6924 || training accuracy 0.00% || lr [5.877471754111438e-43]
# Epoch[2/20](160/244) || training loss 0.6934 || training accuracy 2.50% || lr [1.4693679385278595e-43]
# Epoch[2/20](170/244) || training loss 0.6915 || training accuracy 2.50% || lr [3.6734198463196486e-44]
# Epoch[2/20](180/244) || training loss 0.6929 || training accuracy 0.00% || lr [9.183549615799122e-45]
# Epoch[2/20](190/244) || training loss 0.6972 || training accuracy 0.00% || lr [2.2958874039497804e-45]
# Epoch[2/20](200/244) || training loss 0.6918 || training accuracy 0.00% || lr [5.739718509874451e-46]
# Epoch[2/20](210/244) || training loss 0.6928 || training accuracy 0.00% || lr [1.4349296274686127e-46]
# Epoch[2/20](220/244) || training loss 0.6928 || training accuracy 0.00% || lr [3.587324068671532e-47]
# Epoch[2/20](230/244) || training loss 0.6925 || training accuracy 0.00% || lr [8.96831017167883e-48]
# Epoch[2/20](240/244) || training loss 0.692 || training accuracy 2.50% || lr [2.2420775429197074e-48]
# Epoch[3/20](10/244) || training loss 0.6805 || training accuracy 77.50% || lr [2.8025969286496343e-49]
# Epoch[3/20](20/244) || training loss 0.694 || training accuracy 0.00% || lr [7.006492321624086e-50]
# Epoch[3/20](30/244) || training loss 0.6922 || training accuracy 0.00% || lr [1.7516230804060214e-50]
# Epoch[3/20](40/244) || training loss 0.6933 || training accuracy 0.00% || lr [4.3790577010150536e-51]
# Epoch[3/20](50/244) || training loss 0.6929 || training accuracy 0.00% || lr [1.0947644252537634e-51]
# Epoch[3/20](60/244) || training loss 0.6931 || training accuracy 0.00% || lr [2.7369110631344085e-52]
# Epoch[3/20](70/244) || training loss 0.6931 || training accuracy 0.00% || lr [6.842277657836021e-53]
# Epoch[3/20](80/244) || training loss 0.6935 || training accuracy 0.00% || lr [1.7105694144590053e-53]
# Epoch[3/20](90/244) || training loss 0.6931 || training accuracy 0.00% || lr [4.276423536147513e-54]
# Epoch[3/20](100/244) || training loss 0.6931 || training accuracy 0.00% || lr [1.0691058840368783e-54]
# Epoch[3/20](110/244) || training loss 0.6926 || training accuracy 0.00% || lr [2.6727647100921958e-55]
# Epoch[3/20](120/244) || training loss 0.6914 || training accuracy 0.00% || lr [6.681911775230489e-56]
# Epoch[3/20](130/244) || training loss 0.6909 || training accuracy 0.00% || lr [1.6704779438076224e-56]
# Epoch[3/20](140/244) || training loss 0.6929 || training accuracy 0.00% || lr [4.176194859519056e-57]
# Epoch[3/20](150/244) || training loss 0.6924 || training accuracy 0.00% || lr [1.044048714879764e-57]
# Epoch[3/20](160/244) || training loss 0.6934 || training accuracy 2.50% || lr [2.61012178719941e-58]
# Epoch[3/20](170/244) || training loss 0.6915 || training accuracy 2.50% || lr [6.525304467998525e-59]
# Epoch[3/20](180/244) || training loss 0.6929 || training accuracy 0.00% || lr [1.6313261169996312e-59]
# Epoch[3/20](190/244) || training loss 0.6972 || training accuracy 0.00% || lr [4.078315292499078e-60]
# Epoch[3/20](200/244) || training loss 0.6918 || training accuracy 0.00% || lr [1.0195788231247695e-60]
# Epoch[3/20](210/244) || training loss 0.6928 || training accuracy 0.00% || lr [2.5489470578119238e-61]
# Epoch[3/20](220/244) || training loss 0.6928 || training accuracy 0.00% || lr [6.372367644529809e-62]
# Epoch[3/20](230/244) || training loss 0.6925 || training accuracy 0.00% || lr [1.5930919111324524e-62]
# Epoch[3/20](240/244) || training loss 0.692 || training accuracy 2.50% || lr [3.982729777831131e-63]
# Epoch[4/20](10/244) || training loss 0.6805 || training accuracy 77.50% || lr [4.9784122222889136e-64]
# Epoch[4/20](20/244) || training loss 0.694 || training accuracy 0.00% || lr [1.2446030555722284e-64]
# Epoch[4/20](30/244) || training loss 0.6922 || training accuracy 0.00% || lr [3.111507638930571e-65]
# Epoch[4/20](40/244) || training loss 0.6933 || training accuracy 0.00% || lr [7.778769097326428e-66]
# Epoch[4/20](50/244) || training loss 0.6929 || training accuracy 0.00% || lr [1.944692274331607e-66]
# Epoch[4/20](60/244) || training loss 0.6931 || training accuracy 0.00% || lr [4.861730685829017e-67]
# Epoch[4/20](70/244) || training loss 0.6931 || training accuracy 0.00% || lr [1.2154326714572543e-67]
# Epoch[4/20](80/244) || training loss 0.6935 || training accuracy 0.00% || lr [3.0385816786431357e-68]
# Epoch[4/20](90/244) || training loss 0.6931 || training accuracy 0.00% || lr [7.596454196607839e-69]
# Epoch[4/20](100/244) || training loss 0.6931 || training accuracy 0.00% || lr [1.8991135491519598e-69]
# Epoch[4/20](110/244) || training loss 0.6926 || training accuracy 0.00% || lr [4.7477838728798996e-70]
# Epoch[4/20](120/244) || training loss 0.6914 || training accuracy 0.00% || lr [1.1869459682199749e-70]
# Epoch[4/20](130/244) || training loss 0.6909 || training accuracy 0.00% || lr [2.9673649205499373e-71]
# Epoch[4/20](140/244) || training loss 0.6929 || training accuracy 0.00% || lr [7.418412301374843e-72]
# Epoch[4/20](150/244) || training loss 0.6924 || training accuracy 0.00% || lr [1.8546030753437108e-72]
# Epoch[4/20](160/244) || training loss 0.6934 || training accuracy 2.50% || lr [4.636507688359277e-73]
# Epoch[4/20](170/244) || training loss 0.6915 || training accuracy 2.50% || lr [1.1591269220898192e-73]
# Epoch[4/20](180/244) || training loss 0.6929 || training accuracy 0.00% || lr [2.897817305224548e-74]
# Epoch[4/20](190/244) || training loss 0.6972 || training accuracy 0.00% || lr [7.24454326306137e-75]
# Epoch[4/20](200/244) || training loss 0.6918 || training accuracy 0.00% || lr [1.8111358157653426e-75]
# Epoch[4/20](210/244) || training loss 0.6928 || training accuracy 0.00% || lr [4.5278395394133564e-76]
# Epoch[4/20](220/244) || training loss 0.6928 || training accuracy 0.00% || lr [1.1319598848533391e-76]
# Epoch[4/20](230/244) || training loss 0.6925 || training accuracy 0.00% || lr [2.8298997121333478e-77]
# Epoch[4/20](240/244) || training loss 0.692 || training accuracy 2.50% || lr [7.074749280333369e-78]
# Epoch[5/20](10/244) || training loss 0.6805 || training accuracy 77.50% || lr [1.7686873200833423e-78]
# Epoch[5/20](20/244) || training loss 0.694 || training accuracy 0.00% || lr [4.421718300208356e-79]
# Epoch[5/20](30/244) || training loss 0.6922 || training accuracy 0.00% || lr [1.105429575052089e-79]
# Epoch[5/20](40/244) || training loss 0.6933 || training accuracy 0.00% || lr [2.7635739376302224e-80]
# Epoch[5/20](50/244) || training loss 0.6929 || training accuracy 0.00% || lr [6.908934844075556e-81]
# Epoch[5/20](60/244) || training loss 0.6931 || training accuracy 0.00% || lr [1.727233711018889e-81]
# Epoch[5/20](70/244) || training loss 0.6931 || training accuracy 0.00% || lr [4.3180842775472225e-82]
# Epoch[5/20](80/244) || training loss 0.6935 || training accuracy 0.00% || lr [1.0795210693868056e-82]
# Epoch[5/20](90/244) || training loss 0.6931 || training accuracy 0.00% || lr [2.698802673467014e-83]
# Epoch[5/20](100/244) || training loss 0.6931 || training accuracy 0.00% || lr [6.747006683667535e-84]
# Epoch[5/20](110/244) || training loss 0.6926 || training accuracy 0.00% || lr [1.6867516709168838e-84]
# Epoch[5/20](120/244) || training loss 0.6914 || training accuracy 0.00% || lr [4.2168791772922095e-85]
# Epoch[5/20](130/244) || training loss 0.6909 || training accuracy 0.00% || lr [1.0542197943230524e-85]
# Epoch[5/20](140/244) || training loss 0.6929 || training accuracy 0.00% || lr [2.635549485807631e-86]
# Epoch[5/20](150/244) || training loss 0.6924 || training accuracy 0.00% || lr [6.588873714519077e-87]
# Epoch[5/20](160/244) || training loss 0.6934 || training accuracy 2.50% || lr [1.6472184286297693e-87]
# Epoch[5/20](170/244) || training loss 0.6915 || training accuracy 2.50% || lr [4.1180460715744233e-88]
# Epoch[5/20](180/244) || training loss 0.6929 || training accuracy 0.00% || lr [1.0295115178936058e-88]
# Epoch[5/20](190/244) || training loss 0.6972 || training accuracy 0.00% || lr [2.5737787947340146e-89]
# Epoch[5/20](200/244) || training loss 0.6918 || training accuracy 0.00% || lr [6.4344469868350365e-90]
# Epoch[5/20](210/244) || training loss 0.6928 || training accuracy 0.00% || lr [1.6086117467087591e-90]
# Epoch[5/20](220/244) || training loss 0.6928 || training accuracy 0.00% || lr [4.021529366771898e-91]
# Epoch[5/20](230/244) || training loss 0.6925 || training accuracy 0.00% || lr [1.0053823416929744e-91]
# Epoch[5/20](240/244) || training loss 0.692 || training accuracy 2.50% || lr [2.513455854232436e-92]
# Epoch[6/20](10/244) || training loss 0.6805 || training accuracy 77.50% || lr [3.141819817790545e-93]
# Epoch[6/20](20/244) || training loss 0.694 || training accuracy 0.00% || lr [7.854549544476363e-94]
# Epoch[6/20](30/244) || training loss 0.6922 || training accuracy 0.00% || lr [1.9636373861190907e-94]
# Epoch[6/20](40/244) || training loss 0.6933 || training accuracy 0.00% || lr [4.909093465297727e-95]
# Epoch[6/20](50/244) || training loss 0.6929 || training accuracy 0.00% || lr [1.2272733663244317e-95]
# Epoch[6/20](60/244) || training loss 0.6931 || training accuracy 0.00% || lr [3.0681834158110792e-96]
# Epoch[6/20](70/244) || training loss 0.6931 || training accuracy 0.00% || lr [7.670458539527698e-97]
# Epoch[6/20](80/244) || training loss 0.6935 || training accuracy 0.00% || lr [1.9176146348819245e-97]
# Epoch[6/20](90/244) || training loss 0.6931 || training accuracy 0.00% || lr [4.794036587204811e-98]
# Epoch[6/20](100/244) || training loss 0.6931 || training accuracy 0.00% || lr [1.1985091468012028e-98]
# Epoch[6/20](110/244) || training loss 0.6926 || training accuracy 0.00% || lr [2.996272867003007e-99]
# Epoch[6/20](120/244) || training loss 0.6914 || training accuracy 0.00% || lr [7.490682167507518e-100]
# Epoch[6/20](130/244) || training loss 0.6909 || training accuracy 0.00% || lr [1.8726705418768794e-100]
# Epoch[6/20](140/244) || training loss 0.6929 || training accuracy 0.00% || lr [4.6816763546921986e-101]
# Epoch[6/20](150/244) || training loss 0.6924 || training accuracy 0.00% || lr [1.1704190886730496e-101]
# Epoch[6/20](160/244) || training loss 0.6934 || training accuracy 2.50% || lr [2.926047721682624e-102]
# Epoch[6/20](170/244) || training loss 0.6915 || training accuracy 2.50% || lr [7.31511930420656e-103]
# Epoch[6/20](180/244) || training loss 0.6929 || training accuracy 0.00% || lr [1.82877982605164e-103]
# Epoch[6/20](190/244) || training loss 0.6972 || training accuracy 0.00% || lr [4.5719495651291e-104]
# Epoch[6/20](200/244) || training loss 0.6918 || training accuracy 0.00% || lr [1.142987391282275e-104]
# Epoch[6/20](210/244) || training loss 0.6928 || training accuracy 0.00% || lr [2.8574684782056876e-105]
# Epoch[6/20](220/244) || training loss 0.6928 || training accuracy 0.00% || lr [7.143671195514219e-106]
# Epoch[6/20](230/244) || training loss 0.6925 || training accuracy 0.00% || lr [1.7859177988785547e-106]
# Epoch[6/20](240/244) || training loss 0.692 || training accuracy 2.50% || lr [4.464794497196387e-107]
# Epoch[7/20](10/244) || training loss 0.6805 || training accuracy 77.50% || lr [5.5809931214954836e-108]
# Epoch[7/20](20/244) || training loss 0.694 || training accuracy 0.00% || lr [1.3952482803738709e-108]
# Epoch[7/20](30/244) || training loss 0.6922 || training accuracy 0.00% || lr [3.4881207009346772e-109]
# Epoch[7/20](40/244) || training loss 0.6933 || training accuracy 0.00% || lr [8.720301752336693e-110]
# Epoch[7/20](50/244) || training loss 0.6929 || training accuracy 0.00% || lr [2.1800754380841733e-110]
# Epoch[7/20](60/244) || training loss 0.6931 || training accuracy 0.00% || lr [5.450188595210433e-111]
# Epoch[7/20](70/244) || training loss 0.6931 || training accuracy 0.00% || lr [1.3625471488026083e-111]
# Epoch[7/20](80/244) || training loss 0.6935 || training accuracy 0.00% || lr [3.4063678720065207e-112]
# Epoch[7/20](90/244) || training loss 0.6931 || training accuracy 0.00% || lr [8.515919680016302e-113]
# Epoch[7/20](100/244) || training loss 0.6931 || training accuracy 0.00% || lr [2.1289799200040755e-113]
# Epoch[7/20](110/244) || training loss 0.6926 || training accuracy 0.00% || lr [5.322449800010189e-114]
# Epoch[7/20](120/244) || training loss 0.6914 || training accuracy 0.00% || lr [1.3306124500025472e-114]
# Epoch[7/20](130/244) || training loss 0.6909 || training accuracy 0.00% || lr [3.326531125006368e-115]
# Epoch[7/20](140/244) || training loss 0.6929 || training accuracy 0.00% || lr [8.31632781251592e-116]
# Epoch[7/20](150/244) || training loss 0.6924 || training accuracy 0.00% || lr [2.07908195312898e-116]
# Epoch[7/20](160/244) || training loss 0.6934 || training accuracy 2.50% || lr [5.19770488282245e-117]
# Epoch[7/20](170/244) || training loss 0.6915 || training accuracy 2.50% || lr [1.2994262207056125e-117]
# Epoch[7/20](180/244) || training loss 0.6929 || training accuracy 0.00% || lr [3.248565551764031e-118]
# Epoch[7/20](190/244) || training loss 0.6972 || training accuracy 0.00% || lr [8.121413879410078e-119]
# Epoch[7/20](200/244) || training loss 0.6918 || training accuracy 0.00% || lr [2.0303534698525195e-119]
# Epoch[7/20](210/244) || training loss 0.6928 || training accuracy 0.00% || lr [5.075883674631299e-120]
# Epoch[7/20](220/244) || training loss 0.6928 || training accuracy 0.00% || lr [1.2689709186578247e-120]
# Epoch[7/20](230/244) || training loss 0.6925 || training accuracy 0.00% || lr [3.1724272966445617e-121]
# Epoch[7/20](240/244) || training loss 0.692 || training accuracy 2.50% || lr [7.931068241611404e-122]
# Epoch[8/20](10/244) || training loss 0.6805 || training accuracy 77.50% || lr [9.913835302014255e-123]
# Epoch[8/20](20/244) || training loss 0.694 || training accuracy 0.00% || lr [2.4784588255035638e-123]
# Epoch[8/20](30/244) || training loss 0.6922 || training accuracy 0.00% || lr [6.1961470637589095e-124]
# Epoch[8/20](40/244) || training loss 0.6933 || training accuracy 0.00% || lr [1.5490367659397274e-124]
# Epoch[8/20](50/244) || training loss 0.6929 || training accuracy 0.00% || lr [3.8725919148493185e-125]
# Epoch[8/20](60/244) || training loss 0.6931 || training accuracy 0.00% || lr [9.681479787123296e-126]
# Epoch[8/20](70/244) || training loss 0.6931 || training accuracy 0.00% || lr [2.420369946780824e-126]
# Epoch[8/20](80/244) || training loss 0.6935 || training accuracy 0.00% || lr [6.05092486695206e-127]
# Epoch[8/20](90/244) || training loss 0.6931 || training accuracy 0.00% || lr [1.512731216738015e-127]
# Epoch[8/20](100/244) || training loss 0.6931 || training accuracy 0.00% || lr [3.7818280418450376e-128]
# Epoch[8/20](110/244) || training loss 0.6926 || training accuracy 0.00% || lr [9.454570104612594e-129]
# Epoch[8/20](120/244) || training loss 0.6914 || training accuracy 0.00% || lr [2.3636425261531485e-129]
# Epoch[8/20](130/244) || training loss 0.6909 || training accuracy 0.00% || lr [5.909106315382871e-130]
# Epoch[8/20](140/244) || training loss 0.6929 || training accuracy 0.00% || lr [1.4772765788457178e-130]
# Epoch[8/20](150/244) || training loss 0.6924 || training accuracy 0.00% || lr [3.6931914471142945e-131]
# Epoch[8/20](160/244) || training loss 0.6934 || training accuracy 2.50% || lr [9.232978617785736e-132]
# Epoch[8/20](170/244) || training loss 0.6915 || training accuracy 2.50% || lr [2.308244654446434e-132]
# Epoch[8/20](180/244) || training loss 0.6929 || training accuracy 0.00% || lr [5.770611636116085e-133]
# Epoch[8/20](190/244) || training loss 0.6972 || training accuracy 0.00% || lr [1.4426529090290213e-133]
# Epoch[8/20](200/244) || training loss 0.6918 || training accuracy 0.00% || lr [3.606632272572553e-134]
# Epoch[8/20](210/244) || training loss 0.6928 || training accuracy 0.00% || lr [9.016580681431383e-135]
# Epoch[8/20](220/244) || training loss 0.6928 || training accuracy 0.00% || lr [2.2541451703578458e-135]
# Epoch[8/20](230/244) || training loss 0.6925 || training accuracy 0.00% || lr [5.6353629258946144e-136]
# Epoch[8/20](240/244) || training loss 0.692 || training accuracy 2.50% || lr [1.4088407314736536e-136]
# Epoch[9/20](10/244) || training loss 0.6805 || training accuracy 77.50% || lr [1.761050914342067e-137]
# Epoch[9/20](20/244) || training loss 0.694 || training accuracy 0.00% || lr [4.4026272858551675e-138]
# Epoch[9/20](30/244) || training loss 0.6922 || training accuracy 0.00% || lr [1.1006568214637919e-138]
# Epoch[9/20](40/244) || training loss 0.6933 || training accuracy 0.00% || lr [2.7516420536594797e-139]
# Epoch[9/20](50/244) || training loss 0.6929 || training accuracy 0.00% || lr [6.879105134148699e-140]
# Epoch[9/20](60/244) || training loss 0.6931 || training accuracy 0.00% || lr [1.7197762835371748e-140]
# Epoch[9/20](70/244) || training loss 0.6931 || training accuracy 0.00% || lr [4.299440708842937e-141]
# Epoch[9/20](80/244) || training loss 0.6935 || training accuracy 0.00% || lr [1.0748601772107343e-141]
# Epoch[9/20](90/244) || training loss 0.6931 || training accuracy 0.00% || lr [2.6871504430268356e-142]
# Epoch[9/20](100/244) || training loss 0.6931 || training accuracy 0.00% || lr [6.717876107567089e-143]
# Epoch[9/20](110/244) || training loss 0.6926 || training accuracy 0.00% || lr [1.6794690268917723e-143]
# Epoch[9/20](120/244) || training loss 0.6914 || training accuracy 0.00% || lr [4.1986725672294307e-144]
# Epoch[9/20](130/244) || training loss 0.6909 || training accuracy 0.00% || lr [1.0496681418073577e-144]
# Epoch[9/20](140/244) || training loss 0.6929 || training accuracy 0.00% || lr [2.624170354518394e-145]
# Epoch[9/20](150/244) || training loss 0.6924 || training accuracy 0.00% || lr [6.560425886295985e-146]
# Epoch[9/20](160/244) || training loss 0.6934 || training accuracy 2.50% || lr [1.6401064715739964e-146]
# Epoch[9/20](170/244) || training loss 0.6915 || training accuracy 2.50% || lr [4.100266178934991e-147]
# Epoch[9/20](180/244) || training loss 0.6929 || training accuracy 0.00% || lr [1.0250665447337477e-147]
# Epoch[9/20](190/244) || training loss 0.6972 || training accuracy 0.00% || lr [2.5626663618343693e-148]
# Epoch[9/20](200/244) || training loss 0.6918 || training accuracy 0.00% || lr [6.406665904585923e-149]
# Epoch[9/20](210/244) || training loss 0.6928 || training accuracy 0.00% || lr [1.6016664761464808e-149]
# Epoch[9/20](220/244) || training loss 0.6928 || training accuracy 0.00% || lr [4.004166190366202e-150]
# Epoch[9/20](230/244) || training loss 0.6925 || training accuracy 0.00% || lr [1.0010415475915505e-150]
# Epoch[9/20](240/244) || training loss 0.692 || training accuracy 2.50% || lr [2.5026038689788763e-151]
# Epoch[10/20](10/244) || training loss 0.6805 || training accuracy 77.50% || lr [6.256509672447191e-152]
# Epoch[10/20](20/244) || training loss 0.694 || training accuracy 0.00% || lr [1.5641274181117977e-152]
# Epoch[10/20](30/244) || training loss 0.6922 || training accuracy 0.00% || lr [3.910318545279494e-153]
# Epoch[10/20](40/244) || training loss 0.6933 || training accuracy 0.00% || lr [9.775796363198735e-154]
# Epoch[10/20](50/244) || training loss 0.6929 || training accuracy 0.00% || lr [2.443949090799684e-154]
# Epoch[10/20](60/244) || training loss 0.6931 || training accuracy 0.00% || lr [6.10987272699921e-155]
# Epoch[10/20](70/244) || training loss 0.6931 || training accuracy 0.00% || lr [1.5274681817498024e-155]
# Epoch[10/20](80/244) || training loss 0.6935 || training accuracy 0.00% || lr [3.818670454374506e-156]
# Epoch[10/20](90/244) || training loss 0.6931 || training accuracy 0.00% || lr [9.546676135936265e-157]
# Epoch[10/20](100/244) || training loss 0.6931 || training accuracy 0.00% || lr [2.3866690339840663e-157]
# Epoch[10/20](110/244) || training loss 0.6926 || training accuracy 0.00% || lr [5.966672584960166e-158]
# Epoch[10/20](120/244) || training loss 0.6914 || training accuracy 0.00% || lr [1.4916681462400414e-158]
# Epoch[10/20](130/244) || training loss 0.6909 || training accuracy 0.00% || lr [3.7291703656001036e-159]
# Epoch[10/20](140/244) || training loss 0.6929 || training accuracy 0.00% || lr [9.322925914000259e-160]
# Epoch[10/20](150/244) || training loss 0.6924 || training accuracy 0.00% || lr [2.3307314785000647e-160]
# Epoch[10/20](160/244) || training loss 0.6934 || training accuracy 2.50% || lr [5.826828696250162e-161]
# Epoch[10/20](170/244) || training loss 0.6915 || training accuracy 2.50% || lr [1.4567071740625404e-161]
# Epoch[10/20](180/244) || training loss 0.6929 || training accuracy 0.00% || lr [3.641767935156351e-162]
# Epoch[10/20](190/244) || training loss 0.6972 || training accuracy 0.00% || lr [9.104419837890878e-163]
# Epoch[10/20](200/244) || training loss 0.6918 || training accuracy 0.00% || lr [2.2761049594727195e-163]
# Epoch[10/20](210/244) || training loss 0.6928 || training accuracy 0.00% || lr [5.690262398681799e-164]
# Epoch[10/20](220/244) || training loss 0.6928 || training accuracy 0.00% || lr [1.4225655996704497e-164]
# Epoch[10/20](230/244) || training loss 0.6925 || training accuracy 0.00% || lr [3.556413999176124e-165]
# Epoch[10/20](240/244) || training loss 0.692 || training accuracy 2.50% || lr [8.89103499794031e-166]
# Epoch[11/20](10/244) || training loss 0.6805 || training accuracy 77.50% || lr [1.1113793747425388e-166]
# Epoch[11/20](20/244) || training loss 0.694 || training accuracy 0.00% || lr [2.778448436856347e-167]
# Epoch[11/20](30/244) || training loss 0.6922 || training accuracy 0.00% || lr [6.946121092140867e-168]
# Epoch[11/20](40/244) || training loss 0.6933 || training accuracy 0.00% || lr [1.7365302730352169e-168]
# Epoch[11/20](50/244) || training loss 0.6929 || training accuracy 0.00% || lr [4.341325682588042e-169]
# Epoch[11/20](60/244) || training loss 0.6931 || training accuracy 0.00% || lr [1.0853314206470105e-169]
# Epoch[11/20](70/244) || training loss 0.6931 || training accuracy 0.00% || lr [2.7133285516175264e-170]
# Epoch[11/20](80/244) || training loss 0.6935 || training accuracy 0.00% || lr [6.783321379043816e-171]
# Epoch[11/20](90/244) || training loss 0.6931 || training accuracy 0.00% || lr [1.695830344760954e-171]
# Epoch[11/20](100/244) || training loss 0.6931 || training accuracy 0.00% || lr [4.239575861902385e-172]
# Epoch[11/20](110/244) || training loss 0.6926 || training accuracy 0.00% || lr [1.0598939654755962e-172]
# Epoch[11/20](120/244) || training loss 0.6914 || training accuracy 0.00% || lr [2.6497349136889906e-173]
# Epoch[11/20](130/244) || training loss 0.6909 || training accuracy 0.00% || lr [6.6243372842224765e-174]
# Epoch[11/20](140/244) || training loss 0.6929 || training accuracy 0.00% || lr [1.6560843210556191e-174]
# Epoch[11/20](150/244) || training loss 0.6924 || training accuracy 0.00% || lr [4.140210802639048e-175]
# Epoch[11/20](160/244) || training loss 0.6934 || training accuracy 2.50% || lr [1.035052700659762e-175]
# Epoch[11/20](170/244) || training loss 0.6915 || training accuracy 2.50% || lr [2.587631751649405e-176]
# Epoch[11/20](180/244) || training loss 0.6929 || training accuracy 0.00% || lr [6.469079379123512e-177]
# Epoch[11/20](190/244) || training loss 0.6972 || training accuracy 0.00% || lr [1.617269844780878e-177]
# Epoch[11/20](200/244) || training loss 0.6918 || training accuracy 0.00% || lr [4.043174611952195e-178]
# Epoch[11/20](210/244) || training loss 0.6928 || training accuracy 0.00% || lr [1.0107936529880488e-178]
# Epoch[11/20](220/244) || training loss 0.6928 || training accuracy 0.00% || lr [2.526984132470122e-179]
# Epoch[11/20](230/244) || training loss 0.6925 || training accuracy 0.00% || lr [6.317460331175305e-180]
# Epoch[11/20](240/244) || training loss 0.692 || training accuracy 2.50% || lr [1.5793650827938262e-180]
# Epoch[12/20](10/244) || training loss 0.6805 || training accuracy 77.50% || lr [1.9742063534922828e-181]
# Epoch[12/20](20/244) || training loss 0.694 || training accuracy 0.00% || lr [4.935515883730707e-182]
# Epoch[12/20](30/244) || training loss 0.6922 || training accuracy 0.00% || lr [1.2338789709326767e-182]
# Epoch[12/20](40/244) || training loss 0.6933 || training accuracy 0.00% || lr [3.084697427331692e-183]
# Epoch[12/20](50/244) || training loss 0.6929 || training accuracy 0.00% || lr [7.71174356832923e-184]
# Epoch[12/20](60/244) || training loss 0.6931 || training accuracy 0.00% || lr [1.9279358920823074e-184]
# Epoch[12/20](70/244) || training loss 0.6931 || training accuracy 0.00% || lr [4.8198397302057685e-185]
# Epoch[12/20](80/244) || training loss 0.6935 || training accuracy 0.00% || lr [1.2049599325514421e-185]
# Epoch[12/20](90/244) || training loss 0.6931 || training accuracy 0.00% || lr [3.0123998313786053e-186]
# Epoch[12/20](100/244) || training loss 0.6931 || training accuracy 0.00% || lr [7.530999578446513e-187]
# Epoch[12/20](110/244) || training loss 0.6926 || training accuracy 0.00% || lr [1.8827498946116283e-187]
# Epoch[12/20](120/244) || training loss 0.6914 || training accuracy 0.00% || lr [4.706874736529071e-188]
# Epoch[12/20](130/244) || training loss 0.6909 || training accuracy 0.00% || lr [1.1767186841322677e-188]
# Epoch[12/20](140/244) || training loss 0.6929 || training accuracy 0.00% || lr [2.9417967103306692e-189]
# Epoch[12/20](150/244) || training loss 0.6924 || training accuracy 0.00% || lr [7.354491775826673e-190]
# Epoch[12/20](160/244) || training loss 0.6934 || training accuracy 2.50% || lr [1.8386229439566683e-190]
# Epoch[12/20](170/244) || training loss 0.6915 || training accuracy 2.50% || lr [4.5965573598916707e-191]
# Epoch[12/20](180/244) || training loss 0.6929 || training accuracy 0.00% || lr [1.1491393399729177e-191]
# Epoch[12/20](190/244) || training loss 0.6972 || training accuracy 0.00% || lr [2.872848349932294e-192]
# Epoch[12/20](200/244) || training loss 0.6918 || training accuracy 0.00% || lr [7.182120874830735e-193]
# Epoch[12/20](210/244) || training loss 0.6928 || training accuracy 0.00% || lr [1.7955302187076839e-193]
# Epoch[12/20](220/244) || training loss 0.6928 || training accuracy 0.00% || lr [4.4888255467692096e-194]
# Epoch[12/20](230/244) || training loss 0.6925 || training accuracy 0.00% || lr [1.1222063866923024e-194]
# Epoch[12/20](240/244) || training loss 0.692 || training accuracy 2.50% || lr [2.805515966730756e-195]
# Epoch[13/20](10/244) || training loss 0.6805 || training accuracy 77.50% || lr [3.506894958413445e-196]
# Epoch[13/20](20/244) || training loss 0.694 || training accuracy 0.00% || lr [8.767237396033613e-197]
# Epoch[13/20](30/244) || training loss 0.6922 || training accuracy 0.00% || lr [2.191809349008403e-197]
# Epoch[13/20](40/244) || training loss 0.6933 || training accuracy 0.00% || lr [5.479523372521008e-198]
# Epoch[13/20](50/244) || training loss 0.6929 || training accuracy 0.00% || lr [1.369880843130252e-198]
# Epoch[13/20](60/244) || training loss 0.6931 || training accuracy 0.00% || lr [3.42470210782563e-199]
# Epoch[13/20](70/244) || training loss 0.6931 || training accuracy 0.00% || lr [8.561755269564075e-200]
# Epoch[13/20](80/244) || training loss 0.6935 || training accuracy 0.00% || lr [2.1404388173910187e-200]
# Epoch[13/20](90/244) || training loss 0.6931 || training accuracy 0.00% || lr [5.351097043477547e-201]
# Epoch[13/20](100/244) || training loss 0.6931 || training accuracy 0.00% || lr [1.3377742608693867e-201]
# Epoch[13/20](110/244) || training loss 0.6926 || training accuracy 0.00% || lr [3.3444356521734667e-202]
# Epoch[13/20](120/244) || training loss 0.6914 || training accuracy 0.00% || lr [8.361089130433667e-203]
# Epoch[13/20](130/244) || training loss 0.6909 || training accuracy 0.00% || lr [2.0902722826084167e-203]
# Epoch[13/20](140/244) || training loss 0.6929 || training accuracy 0.00% || lr [5.225680706521042e-204]
# Epoch[13/20](150/244) || training loss 0.6924 || training accuracy 0.00% || lr [1.3064201766302604e-204]
# Epoch[13/20](160/244) || training loss 0.6934 || training accuracy 2.50% || lr [3.266050441575651e-205]
# Epoch[13/20](170/244) || training loss 0.6915 || training accuracy 2.50% || lr [8.165126103939128e-206]
# Epoch[13/20](180/244) || training loss 0.6929 || training accuracy 0.00% || lr [2.041281525984782e-206]
# Epoch[13/20](190/244) || training loss 0.6972 || training accuracy 0.00% || lr [5.103203814961955e-207]
# Epoch[13/20](200/244) || training loss 0.6918 || training accuracy 0.00% || lr [1.2758009537404887e-207]
# Epoch[13/20](210/244) || training loss 0.6928 || training accuracy 0.00% || lr [3.1895023843512218e-208]
# Epoch[13/20](220/244) || training loss 0.6928 || training accuracy 0.00% || lr [7.973755960878054e-209]
# Epoch[13/20](230/244) || training loss 0.6925 || training accuracy 0.00% || lr [1.9934389902195136e-209]
# Epoch[13/20](240/244) || training loss 0.692 || training accuracy 2.50% || lr [4.983597475548784e-210]
# Epoch[14/20](10/244) || training loss 0.6805 || training accuracy 77.50% || lr [6.22949684443598e-211]
# Epoch[14/20](20/244) || training loss 0.694 || training accuracy 0.00% || lr [1.557374211108995e-211]
# Epoch[14/20](30/244) || training loss 0.6922 || training accuracy 0.00% || lr [3.8934355277724875e-212]
# Epoch[14/20](40/244) || training loss 0.6933 || training accuracy 0.00% || lr [9.733588819431219e-213]
# Epoch[14/20](50/244) || training loss 0.6929 || training accuracy 0.00% || lr [2.4333972048578047e-213]
# Epoch[14/20](60/244) || training loss 0.6931 || training accuracy 0.00% || lr [6.083493012144512e-214]
# Epoch[14/20](70/244) || training loss 0.6931 || training accuracy 0.00% || lr [1.520873253036128e-214]
# Epoch[14/20](80/244) || training loss 0.6935 || training accuracy 0.00% || lr [3.80218313259032e-215]
# Epoch[14/20](90/244) || training loss 0.6931 || training accuracy 0.00% || lr [9.5054578314758e-216]
# Epoch[14/20](100/244) || training loss 0.6931 || training accuracy 0.00% || lr [2.37636445786895e-216]
# Epoch[14/20](110/244) || training loss 0.6926 || training accuracy 0.00% || lr [5.940911144672375e-217]
# Epoch[14/20](120/244) || training loss 0.6914 || training accuracy 0.00% || lr [1.4852277861680937e-217]
# Epoch[14/20](130/244) || training loss 0.6909 || training accuracy 0.00% || lr [3.713069465420234e-218]
# Epoch[14/20](140/244) || training loss 0.6929 || training accuracy 0.00% || lr [9.282673663550586e-219]
# Epoch[14/20](150/244) || training loss 0.6924 || training accuracy 0.00% || lr [2.3206684158876464e-219]
# Epoch[14/20](160/244) || training loss 0.6934 || training accuracy 2.50% || lr [5.801671039719116e-220]
# Epoch[14/20](170/244) || training loss 0.6915 || training accuracy 2.50% || lr [1.450417759929779e-220]
# Epoch[14/20](180/244) || training loss 0.6929 || training accuracy 0.00% || lr [3.6260443998244475e-221]
# Epoch[14/20](190/244) || training loss 0.6972 || training accuracy 0.00% || lr [9.065110999561119e-222]
# Epoch[14/20](200/244) || training loss 0.6918 || training accuracy 0.00% || lr [2.2662777498902797e-222]
# Epoch[14/20](210/244) || training loss 0.6928 || training accuracy 0.00% || lr [5.665694374725699e-223]
# Epoch[14/20](220/244) || training loss 0.6928 || training accuracy 0.00% || lr [1.4164235936814248e-223]
# Epoch[14/20](230/244) || training loss 0.6925 || training accuracy 0.00% || lr [3.541058984203562e-224]
# Epoch[14/20](240/244) || training loss 0.692 || training accuracy 2.50% || lr [8.852647460508905e-225]
# Epoch[15/20](10/244) || training loss 0.6805 || training accuracy 77.50% || lr [2.2131618651272262e-225]
# Epoch[15/20](20/244) || training loss 0.694 || training accuracy 0.00% || lr [5.5329046628180656e-226]
# Epoch[15/20](30/244) || training loss 0.6922 || training accuracy 0.00% || lr [1.3832261657045164e-226]
# Epoch[15/20](40/244) || training loss 0.6933 || training accuracy 0.00% || lr [3.458065414261291e-227]
# Epoch[15/20](50/244) || training loss 0.6929 || training accuracy 0.00% || lr [8.645163535653227e-228]
# Epoch[15/20](60/244) || training loss 0.6931 || training accuracy 0.00% || lr [2.161290883913307e-228]
# Epoch[15/20](70/244) || training loss 0.6931 || training accuracy 0.00% || lr [5.403227209783267e-229]
# Epoch[15/20](80/244) || training loss 0.6935 || training accuracy 0.00% || lr [1.3508068024458168e-229]
# Epoch[15/20](90/244) || training loss 0.6931 || training accuracy 0.00% || lr [3.377017006114542e-230]
# Epoch[15/20](100/244) || training loss 0.6931 || training accuracy 0.00% || lr [8.442542515286355e-231]
# Epoch[15/20](110/244) || training loss 0.6926 || training accuracy 0.00% || lr [2.1106356288215887e-231]
# Epoch[15/20](120/244) || training loss 0.6914 || training accuracy 0.00% || lr [5.276589072053972e-232]
# Epoch[15/20](130/244) || training loss 0.6909 || training accuracy 0.00% || lr [1.319147268013493e-232]
# Epoch[15/20](140/244) || training loss 0.6929 || training accuracy 0.00% || lr [3.2978681700337324e-233]
# Epoch[15/20](150/244) || training loss 0.6924 || training accuracy 0.00% || lr [8.244670425084331e-234]
# Epoch[15/20](160/244) || training loss 0.6934 || training accuracy 2.50% || lr [2.0611676062710828e-234]
# Epoch[15/20](170/244) || training loss 0.6915 || training accuracy 2.50% || lr [5.152919015677707e-235]
# Epoch[15/20](180/244) || training loss 0.6929 || training accuracy 0.00% || lr [1.2882297539194267e-235]
# Epoch[15/20](190/244) || training loss 0.6972 || training accuracy 0.00% || lr [3.220574384798567e-236]
# Epoch[15/20](200/244) || training loss 0.6918 || training accuracy 0.00% || lr [8.051435961996417e-237]
# Epoch[15/20](210/244) || training loss 0.6928 || training accuracy 0.00% || lr [2.0128589904991043e-237]
# Epoch[15/20](220/244) || training loss 0.6928 || training accuracy 0.00% || lr [5.0321474762477606e-238]
# Epoch[15/20](230/244) || training loss 0.6925 || training accuracy 0.00% || lr [1.2580368690619402e-238]
# Epoch[15/20](240/244) || training loss 0.692 || training accuracy 2.50% || lr [3.1450921726548504e-239]
# Epoch[16/20](10/244) || training loss 0.6805 || training accuracy 77.50% || lr [3.931365215818563e-240]
# Epoch[16/20](20/244) || training loss 0.694 || training accuracy 0.00% || lr [9.828413039546407e-241]
# Epoch[16/20](30/244) || training loss 0.6922 || training accuracy 0.00% || lr [2.457103259886602e-241]
# Epoch[16/20](40/244) || training loss 0.6933 || training accuracy 0.00% || lr [6.142758149716505e-242]
# Epoch[16/20](50/244) || training loss 0.6929 || training accuracy 0.00% || lr [1.5356895374291262e-242]
# Epoch[16/20](60/244) || training loss 0.6931 || training accuracy 0.00% || lr [3.8392238435728154e-243]
# Epoch[16/20](70/244) || training loss 0.6931 || training accuracy 0.00% || lr [9.598059608932039e-244]
# Epoch[16/20](80/244) || training loss 0.6935 || training accuracy 0.00% || lr [2.3995149022330096e-244]
# Epoch[16/20](90/244) || training loss 0.6931 || training accuracy 0.00% || lr [5.998787255582524e-245]
# Epoch[16/20](100/244) || training loss 0.6931 || training accuracy 0.00% || lr [1.499696813895631e-245]
# Epoch[16/20](110/244) || training loss 0.6926 || training accuracy 0.00% || lr [3.7492420347390776e-246]
# Epoch[16/20](120/244) || training loss 0.6914 || training accuracy 0.00% || lr [9.373105086847694e-247]
# Epoch[16/20](130/244) || training loss 0.6909 || training accuracy 0.00% || lr [2.3432762717119235e-247]
# Epoch[16/20](140/244) || training loss 0.6929 || training accuracy 0.00% || lr [5.858190679279809e-248]
# Epoch[16/20](150/244) || training loss 0.6924 || training accuracy 0.00% || lr [1.4645476698199522e-248]
# Epoch[16/20](160/244) || training loss 0.6934 || training accuracy 2.50% || lr [3.6613691745498804e-249]
# Epoch[16/20](170/244) || training loss 0.6915 || training accuracy 2.50% || lr [9.153422936374701e-250]
# Epoch[16/20](180/244) || training loss 0.6929 || training accuracy 0.00% || lr [2.2883557340936753e-250]
# Epoch[16/20](190/244) || training loss 0.6972 || training accuracy 0.00% || lr [5.720889335234188e-251]
# Epoch[16/20](200/244) || training loss 0.6918 || training accuracy 0.00% || lr [1.430222333808547e-251]
# Epoch[16/20](210/244) || training loss 0.6928 || training accuracy 0.00% || lr [3.5755558345213676e-252]
# Epoch[16/20](220/244) || training loss 0.6928 || training accuracy 0.00% || lr [8.938889586303419e-253]
# Epoch[16/20](230/244) || training loss 0.6925 || training accuracy 0.00% || lr [2.2347223965758548e-253]
# Epoch[16/20](240/244) || training loss 0.692 || training accuracy 2.50% || lr [5.586805991439637e-254]
# Epoch[17/20](10/244) || training loss 0.6805 || training accuracy 77.50% || lr [6.983507489299546e-255]
# Epoch[17/20](20/244) || training loss 0.694 || training accuracy 0.00% || lr [1.7458768723248865e-255]
# Epoch[17/20](30/244) || training loss 0.6922 || training accuracy 0.00% || lr [4.3646921808122163e-256]
# Epoch[17/20](40/244) || training loss 0.6933 || training accuracy 0.00% || lr [1.0911730452030541e-256]
# Epoch[17/20](50/244) || training loss 0.6929 || training accuracy 0.00% || lr [2.7279326130076352e-257]
# Epoch[17/20](60/244) || training loss 0.6931 || training accuracy 0.00% || lr [6.819831532519088e-258]
# Epoch[17/20](70/244) || training loss 0.6931 || training accuracy 0.00% || lr [1.704957883129772e-258]
# Epoch[17/20](80/244) || training loss 0.6935 || training accuracy 0.00% || lr [4.26239470782443e-259]
# Epoch[17/20](90/244) || training loss 0.6931 || training accuracy 0.00% || lr [1.0655986769561075e-259]
# Epoch[17/20](100/244) || training loss 0.6931 || training accuracy 0.00% || lr [2.6639966923902688e-260]
# Epoch[17/20](110/244) || training loss 0.6926 || training accuracy 0.00% || lr [6.659991730975672e-261]
# Epoch[17/20](120/244) || training loss 0.6914 || training accuracy 0.00% || lr [1.664997932743918e-261]
# Epoch[17/20](130/244) || training loss 0.6909 || training accuracy 0.00% || lr [4.162494831859795e-262]
# Epoch[17/20](140/244) || training loss 0.6929 || training accuracy 0.00% || lr [1.0406237079649487e-262]
# Epoch[17/20](150/244) || training loss 0.6924 || training accuracy 0.00% || lr [2.601559269912372e-263]
# Epoch[17/20](160/244) || training loss 0.6934 || training accuracy 2.50% || lr [6.50389817478093e-264]
# Epoch[17/20](170/244) || training loss 0.6915 || training accuracy 2.50% || lr [1.6259745436952324e-264]
# Epoch[17/20](180/244) || training loss 0.6929 || training accuracy 0.00% || lr [4.064936359238081e-265]
# Epoch[17/20](190/244) || training loss 0.6972 || training accuracy 0.00% || lr [1.0162340898095202e-265]
# Epoch[17/20](200/244) || training loss 0.6918 || training accuracy 0.00% || lr [2.5405852245238006e-266]
# Epoch[17/20](210/244) || training loss 0.6928 || training accuracy 0.00% || lr [6.3514630613095015e-267]
# Epoch[17/20](220/244) || training loss 0.6928 || training accuracy 0.00% || lr [1.5878657653273754e-267]
# Epoch[17/20](230/244) || training loss 0.6925 || training accuracy 0.00% || lr [3.9696644133184385e-268]
# Epoch[17/20](240/244) || training loss 0.692 || training accuracy 2.50% || lr [9.924161033296096e-269]
# Epoch[18/20](10/244) || training loss 0.6805 || training accuracy 77.50% || lr [1.240520129162012e-269]
# Epoch[18/20](20/244) || training loss 0.694 || training accuracy 0.00% || lr [3.10130032290503e-270]
# Epoch[18/20](30/244) || training loss 0.6922 || training accuracy 0.00% || lr [7.753250807262575e-271]
# Epoch[18/20](40/244) || training loss 0.6933 || training accuracy 0.00% || lr [1.9383127018156438e-271]
# Epoch[18/20](50/244) || training loss 0.6929 || training accuracy 0.00% || lr [4.8457817545391094e-272]
# Epoch[18/20](60/244) || training loss 0.6931 || training accuracy 0.00% || lr [1.2114454386347774e-272]
# Epoch[18/20](70/244) || training loss 0.6931 || training accuracy 0.00% || lr [3.0286135965869434e-273]
# Epoch[18/20](80/244) || training loss 0.6935 || training accuracy 0.00% || lr [7.571533991467359e-274]
# Epoch[18/20](90/244) || training loss 0.6931 || training accuracy 0.00% || lr [1.8928834978668396e-274]
# Epoch[18/20](100/244) || training loss 0.6931 || training accuracy 0.00% || lr [4.732208744667099e-275]
# Epoch[18/20](110/244) || training loss 0.6926 || training accuracy 0.00% || lr [1.1830521861667748e-275]
# Epoch[18/20](120/244) || training loss 0.6914 || training accuracy 0.00% || lr [2.957630465416937e-276]
# Epoch[18/20](130/244) || training loss 0.6909 || training accuracy 0.00% || lr [7.394076163542342e-277]
# Epoch[18/20](140/244) || training loss 0.6929 || training accuracy 0.00% || lr [1.8485190408855856e-277]
# Epoch[18/20](150/244) || training loss 0.6924 || training accuracy 0.00% || lr [4.621297602213964e-278]
# Epoch[18/20](160/244) || training loss 0.6934 || training accuracy 2.50% || lr [1.155324400553491e-278]
# Epoch[18/20](170/244) || training loss 0.6915 || training accuracy 2.50% || lr [2.8883110013837275e-279]
# Epoch[18/20](180/244) || training loss 0.6929 || training accuracy 0.00% || lr [7.220777503459319e-280]
# Epoch[18/20](190/244) || training loss 0.6972 || training accuracy 0.00% || lr [1.8051943758648297e-280]
# Epoch[18/20](200/244) || training loss 0.6918 || training accuracy 0.00% || lr [4.512985939662074e-281]
# Epoch[18/20](210/244) || training loss 0.6928 || training accuracy 0.00% || lr [1.1282464849155185e-281]
# Epoch[18/20](220/244) || training loss 0.6928 || training accuracy 0.00% || lr [2.8206162122887963e-282]
# Epoch[18/20](230/244) || training loss 0.6925 || training accuracy 0.00% || lr [7.051540530721991e-283]
# Epoch[18/20](240/244) || training loss 0.692 || training accuracy 2.50% || lr [1.7628851326804977e-283]
# Epoch[19/20](10/244) || training loss 0.6805 || training accuracy 77.50% || lr [2.203606415850622e-284]
# Epoch[19/20](20/244) || training loss 0.694 || training accuracy 0.00% || lr [5.509016039626555e-285]
# Epoch[19/20](30/244) || training loss 0.6922 || training accuracy 0.00% || lr [1.3772540099066388e-285]
# Epoch[19/20](40/244) || training loss 0.6933 || training accuracy 0.00% || lr [3.443135024766597e-286]
# Epoch[19/20](50/244) || training loss 0.6929 || training accuracy 0.00% || lr [8.607837561916493e-287]
# Epoch[19/20](60/244) || training loss 0.6931 || training accuracy 0.00% || lr [2.1519593904791232e-287]
# Epoch[19/20](70/244) || training loss 0.6931 || training accuracy 0.00% || lr [5.379898476197808e-288]
# Epoch[19/20](80/244) || training loss 0.6935 || training accuracy 0.00% || lr [1.344974619049452e-288]
# Epoch[19/20](90/244) || training loss 0.6931 || training accuracy 0.00% || lr [3.36243654762363e-289]
# Epoch[19/20](100/244) || training loss 0.6931 || training accuracy 0.00% || lr [8.406091369059075e-290]
# Epoch[19/20](110/244) || training loss 0.6926 || training accuracy 0.00% || lr [2.1015228422647687e-290]
# Epoch[19/20](120/244) || training loss 0.6914 || training accuracy 0.00% || lr [5.253807105661922e-291]
# Epoch[19/20](130/244) || training loss 0.6909 || training accuracy 0.00% || lr [1.3134517764154805e-291]
# Epoch[19/20](140/244) || training loss 0.6929 || training accuracy 0.00% || lr [3.283629441038701e-292]
# Epoch[19/20](150/244) || training loss 0.6924 || training accuracy 0.00% || lr [8.209073602596753e-293]
# Epoch[19/20](160/244) || training loss 0.6934 || training accuracy 2.50% || lr [2.0522684006491882e-293]
# Epoch[19/20](170/244) || training loss 0.6915 || training accuracy 2.50% || lr [5.1306710016229706e-294]
# Epoch[19/20](180/244) || training loss 0.6929 || training accuracy 0.00% || lr [1.2826677504057426e-294]
# Epoch[19/20](190/244) || training loss 0.6972 || training accuracy 0.00% || lr [3.2066693760143566e-295]
# Epoch[19/20](200/244) || training loss 0.6918 || training accuracy 0.00% || lr [8.016673440035891e-296]
# Epoch[19/20](210/244) || training loss 0.6928 || training accuracy 0.00% || lr [2.004168360008973e-296]
# Epoch[19/20](220/244) || training loss 0.6928 || training accuracy 0.00% || lr [5.010420900022432e-297]
# Epoch[19/20](230/244) || training loss 0.6925 || training accuracy 0.00% || lr [1.252605225005608e-297]
# Epoch[19/20](240/244) || training loss 0.692 || training accuracy 2.50% || lr [3.13151306251402e-298]

# %%
print(len(loader))
print(len(dataset))
# Out:
# 244
# 975
